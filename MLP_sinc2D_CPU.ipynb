// %% [markdown]
// <a href="https://colab.research.google.com/github/andreabochicchio02/MLP_in_CUDA/blob/main/MLP_sinc2D_CPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// ## **Multi-Layer Perceptron (MLP) for REGRESSION**

// %% [markdown]
// Multi-Layer Perceptron implemented in C++ to solve regression problem (the sinc2D function)

// %% [markdown]
// ### Including libraries and initializing MLP parameters

// %%
%%writefile MLP.h

#include <iostream>
#include <vector>
#include <array>
#include <cmath>
#include <algorithm>
#include <random>
#include <ctime>
#include <limits>

using namespace std;



const int num_train = 150*150;              // number of training pattern (put a square number here)
const int num_test = 2500;


// //////////////////////////////////////////// //
//                 MLP parameters               //
// //////////////////////////////////////////// //
const int n_output = 1;                     // Number of outputs
const int n_features = 2;                   // Number of input features
const int n_hidden = 300;                   // Number of neurons in the hidden layer
const int epochs = 500;                     // Number of epochs
float eta = 1e-6;                           // Learning rate
const int minibatches = 30;                 // Number of mini-batches

vector<float> cost;
array<array<float, n_features+1>, n_hidden> w1 = {};
array<array<float, n_hidden+1>, n_output> w2 = {};




// Global declaration of variable used in the train step
const int elem = (num_train + minibatches -1 )/minibatches;     // inputs used in each minibatch

// forward
array<array<float, n_features>, elem> x_input;
array<array<float, elem>, n_features> rA0;
array<array<float, elem>, n_features+1> a0;
array<array<float, elem>, n_hidden> rZ1;
array<array<float, elem>, n_hidden> rA1;
array<array<float, elem>, n_hidden+1> a1;
array<array<float, elem>, n_output> rZ2;
array<array<float, elem>, n_output> rA2;


// backpropagation
array<array<float, elem>, n_output> dL_dZ2;
array<array<float, n_hidden+1>, n_output> dL_dW2;
array<array<float, elem>, n_hidden+1> dL_dA1;
array<array<float, elem>, n_hidden> sigma_prime_of_rZ1;
array<array<float, elem>, n_hidden> dL_drZ1;
array<array<float, n_features+1>, n_hidden> dL_dW1;
array<array<float, n_features+1>, n_hidden> delta_W1_unscaled;
array<array<float, n_hidden+1>, n_output> delta_W2_unscaled;
// Out:
// Writing MLP.h

// %% [markdown]
// ###Math function

// %%
%%writefile math_function.cpp

void A_mult_B(const float* A, const float* B, float* C,
              int rigA, int colA, int colB) {
    for (int i = 0; i < rigA; i++) {
        for (int j = 0; j < colB; j++) {
            C[i * colB + j] = 0.0;
            for (int k = 0; k < colA; k++) {
                C[i*colB+j] += A[i*colA+k] * B[k*colB+j];
            }
        }
    }
}


void A_mult_B_T(const float* A, const float* B, float* C,
                   int rigA, int colA, int rigB) {
    for (int i = 0; i < rigA; i++) {
        for (int j = 0; j < rigB; j++) {
            C[i * rigB + j] = 0.0;
            for (int k = 0; k < colA; k++) {
                C[i*rigB+j] += A[i*colA+k] * B[j*colA+k];
            }
        }
    }
}


void A_T_mult_B(const float* A, const float* B, float* C,
                int rigA, int colA, int colB) {

    for (int i = 0; i < colA; i++) {
        for (int j = 0; j < colB; j++) {
            C[i * colB + j] = 0.0;
            for (int k = 0; k < rigA; k++) {
                C[i * colB + j] += A[k * colA + i] * B[k * colB + j];
            }
        }
    }
}


void elem_mult_elem(const float* A, const float* B, float* C, int rig, int col) {
    for (int i = 0; i < rig; ++i) {
        for (int j = 0; j < col; ++j) {
            C[i*col+j] = A[i*col+j] * B[i*col+j];
        }
    }
}
// Out:
// Writing math_function.cpp

// %% [markdown]
// ### Initialization
// Initialize train and test input and output

// %%
%%writefile gen.cpp

//sinc2D function generation
void sinc2D_gen(float* x, float* y, int num_patterns){
    int num_points = sqrt(num_patterns);

    // linspace x1
    vector<float> x1(num_points);
    float start_x1 = -5.0;
    float end_x1 = 5.0;
    float step_x1 = (end_x1 - start_x1) / (num_points - 1);
    for (int i = 0; i < num_points; ++i){
        x1[i] = start_x1 + i * step_x1;
    }


    // linspace x2
    vector<float> x2(num_points);
    float start_x2 = -5.0;
    float end_x2 = 5.0;
    float step_x2 = (end_x2 - start_x2) / (num_points - 1);
    for (int i = 0; i < num_points; ++i){
        x2[i] = start_x2 + i * step_x2;
    }


    // meshgrid
    vector<vector<float>> XX1(num_points, vector<float>(num_points));
    vector<vector<float>> XX2(num_points, vector<float>(num_points));
    for (int i = 0; i < num_points; ++i){
        for (int j = 0; j < num_points; ++j){
            XX1[i][j] = x1[j];
            XX2[i][j] = x2[i];
        }
    }


    // sinc2D
    vector<vector<float>> YY(num_points, vector<float>(num_points));
    for (int i = 0; i < num_points; ++i) {
        for (int j = 0; j < num_points; ++j) {
            float sinc_x1 = (XX1[i][j] == 0) ? 1.0 : sin(XX1[i][j]) / XX1[i][j];
            float sinc_x2 = (XX2[i][j] == 0) ? 1.0 : sin(XX2[i][j]) / XX2[i][j];
            YY[i][j] = 10.0 * sinc_x1 * sinc_x2;
        }
    }


    // initialization x e y
    for (int i = 0; i < num_points; ++i) {
        for (int j = 0; j < num_points; ++j) {
            x[(i*num_points+j)*n_features] = XX1[j][i];
            x[(i*num_points+j)*n_features + 1] = XX2[j][i];
            y[i * num_points + j] = YY[j][i];
        }
    }
}
// Out:
// Writing gen.cpp

// %% [markdown]
// ###Forward function
// Compute the forward step

// %%
%%writefile forward.cpp

// This function computes the sigmoid function for a scalar, a vector or a matrix
array<array<float, elem>, n_hidden> MLP_sigmoid(const array<array<float, elem>, n_hidden> &z){
    array<array<float, elem>, n_hidden> sig;

    for (int i = 0; i < n_hidden; ++i) {
        for (int j = 0; j < elem; ++j) {
            sig[i][j] = 1.0 / (1.0 + exp(-z[i][j]));
        }
    }

    return sig;
}




// Compute the forward step
void MLP_MSELIN_forward(){
    // rA0: is the "reduced A0" and it coincides with the transpose of the tall input matrix (nObs x nInput)
    for (int i = 0; i < elem; ++i) {
        for (int j = 0; j < n_features; ++j) {
            rA0[j][i] = x_input[i][j];
        }
    }


    // MLP_extend
    // A0  = E(rA0) It is the "extended" version of rA0, obtained by it by adding a row of ones as its new first row
    // Extend matrix X by adding the bias
    for (int i = 0; i < n_features+1; ++i) {
        for (int j = 0; j < elem; ++j) {
            a0[i][j] = (i == 0) ? 1 : rA0[i-1][j];
        }
    }


    // rZ1 = \sum(W1,A0).  It is the pre-activation at layer 1 (the hidden one)
    A_mult_B(w1[0].data(), a0[0].data(), rZ1[0].data(), n_hidden, n_features+1, elem);


    // rA1 = \sigma(rZ1).  It is the output of the first layer (the hidden one)
    rA1 = MLP_sigmoid(rZ1);


    // MLP_extend
    // A1  = E(rA1).       It is the extended version of rA1
    // Extend matrix X by adding the bias
    for (int i = 0; i < n_hidden+1; ++i) {
        for (int j = 0; j < elem; ++j) {
            a1[i][j] = (i == 0) ? 1 : rA1[i-1][j];
        }
    }


    // rZ2 = \sum(W2,A1).  It is the pre-activation at layer 2 (the output one)
    A_mult_B(w2[0].data(), a1[0].data(), rZ2[0].data(), n_output, n_hidden+1, elem);


    rA2 = rZ2;
}
// Out:
// Writing forward.cpp

// %% [markdown]
// ### Train
// Learn weights from training data

// %%
%%writefile train.cpp

#include "math_function.cpp"
#include "forward.cpp"

// initialize weights to Unif[-1,1]
void MLP_initialize_weights(){
    array<float, n_hidden*(n_features+1)> w1_temp;
    for(int i=0; i<n_hidden*(n_features+1); ++i){
        w1_temp[i] = 2*(static_cast<float>(rand())/RAND_MAX)-1;
    }

    // reshape
    int index = 0;
    for (int j = 0; j < (n_features+1); ++j) {              //col
        for (int i = 0; i < n_hidden; ++i) {                //row
            w1[i][j] = w1_temp[index++];
        }
    }



    array<float, n_output*(n_hidden+1)> w2_temp;
    for(int i=0; i<n_output*(n_hidden+1); ++i){
        w2_temp[i] = 2*(static_cast<float>(rand())/RAND_MAX)-1;
    }

    // reshape
    index = 0;
    for (int j = 0; j < (n_hidden+1); ++j) {
        for (int i = 0; i < n_output; ++i) {
            w2[i][j] = w2_temp[index++];
        }
    }
}



// Compute sigmoid gradient
array<array<float, elem>, n_hidden> MLP_sigmoid_gradient(const array<array<float, elem>, n_hidden> &Z) {
    array<array<float, elem>, n_hidden> A = MLP_sigmoid(Z);

    array<array<float, elem>, n_hidden> sigGrad;
    for (int i = 0; i < n_hidden; ++i) {
        for (int j = 0; j < elem; ++j) {
            sigGrad[i][j] = A[i][j] * (1.0 - A[i][j]);
        }
    }

    return sigGrad;
}



float MLP_MSE_cost(const array<float, elem> &y) {
    vector<float> diff(y.size());
    for (int i = 0; i < y.size(); ++i) {
        diff[i] = (y[i] - rA2[0][i]);
        diff[i] *= diff[i];
    }


    float cost = (accumulate(diff.begin(), diff.end(), 0.0))/ (2.0 * y.size());
    return cost;
}



// Compute the partial derivative of the loss with respect to the two weighting matrices W2 and W1, using the backpropagation algorithm.
void MLP_MSELIN_backprop(const array<float, elem> &y){
    // rA2 is 1xB
    // A1  is (H+1)xB
    // A0  is (D+1)xB
    // rZ1 is HxB
    // y   is 1xB
    // W1  is Hx(D+1)
    // W2  is 1x(H+1)

    // Step 1: compute dL_dZ2 of size 1xB
    // NB: rA2 coincides with y_pred
    // NB: dL_dZe could be called "grad2", the gradient on the output layer with respect the pre-activation Z2
    for(int i = 0; i<n_output; i++){
        for(int j = 0; j < elem; ++j) {
            dL_dZ2[i][j] = rA2[i][j] - y[j];
        }
    }


    // Step 2: compute dL_dW2 % size 1x(H+1)
    // NB: dL_dW2 could be called "delta_W2_unscaled", because it is of the same size of W2 and stores the unscaled variation
    A_mult_B_T(dL_dZ2[0].data(), a1[0].data(), dL_dW2[0].data(), n_output, elem, n_hidden+1);


    // Step 3: compute dL_dA1 of size (H+1)xB
    A_T_mult_B(w2[0].data(), dL_dZ2[0].data(), dL_dA1[0].data(), n_output, n_hidden+1, elem);



    // Step 4: compute dL_drZ1 of size HxB (also sigma_prime_of_rZ1 has size HxB)
    // NB: dL_drZ1 could have been called "grad1", since it is the gradient at the first layer (the hidden one), with respect to Z1
    sigma_prime_of_rZ1 = MLP_sigmoid_gradient(rZ1);
    elem_mult_elem(dL_dA1[1].data(), sigma_prime_of_rZ1[0].data(),dL_drZ1[0].data(),  n_hidden, elem);



    // Step 5: compute dL_dW1 of size Hx(D+1)
    // NB: dL_dW1 could be called "delta_W1_unscaled", because it is of the same size of W2 and stores the unscaled variation of W1
    A_mult_B_T(dL_drZ1[0].data(), a0[0].data(), dL_dW1[0].data(), n_hidden, elem, n_features+1);



    // Step 6: regularise or not
    for (int i = 0; i < n_hidden; ++i) {
        for (int j = 0; j < n_features+1; ++j) {
            delta_W1_unscaled[i][j] = dL_dW1[i][j];
        }
    }

    for (int j = 0; j < n_output; ++j) {
        for (int i = 0; i < n_hidden+1; ++i) {
            delta_W2_unscaled[j][i] = dL_dW2[j][i];
        }
    }


    /* -----------------------------------------------------------------------------
    NB: grad2 is the gradient at the hidden layer.
    It is a column vector in the case of a single pattern
    (minibatch equal to the training set site) or a matrix,
    to be imagined, in the latter case, a matrix of columns,
    the gradients of each input pattern in the minibatch.

    NB: grad1 is the gradient at the hidden layer (derivative
    of the loss with respect Z1, the pre-activation at the hidden layer).
    It is a column vector in the case of a single pattern
    (minibatch equal to the training set site) or a matrix,
    to be imagined, in the latter case, a matrix of columns,
    the gradients of each input pattern in the minibatch.
    ----------------------------------------------------------------------------- */
}

// learn weights from training data
void MLP_MSELIN_train(const array<array<float, n_features>, num_train> &x, const array<float, num_train> &y){
    // initialize weights w1 and w2
    MLP_initialize_weights();


    cost.push_back(numeric_limits<float>::infinity());

    // loop: epochs
    for(int e=1; e<=epochs; e++) {


        //reshape
        array<array<int, elem>, minibatches> I;
        for (int i = 0; i < num_train; ++i) {
            int row = i % minibatches;
            int col = i / minibatches;
            I[row][col] = i;
        }



        // loop: minibatches
        for(int m=1; m<=minibatches; ++m){
            array<int, elem> idx = I[m-1];

            // Compute the forward step
            for(int i=0; i<elem; i++) {
                copy(x[idx[i]].begin(), x[idx[i]].end(), x_input[i].begin());
            }
            // Feedforward
            MLP_MSELIN_forward();


            // Compute cost function
            array<float, elem> y_index;
            for(int i=0; i<elem; i++) {
                y_index[i] = y[idx[i]];
            }
            float step_cost = MLP_MSE_cost(y_index);
            cost.push_back(step_cost);


            printf("Epoch %d/%d, minibatch %04d, Loss (MSE) %g\n", e, epochs, m, step_cost);


            // Compute gradient via backpropagation
            MLP_MSELIN_backprop(y_index);


            array<array<float, n_features+1>, n_hidden> delta_W1;
            for (int i = 0; i < n_hidden; ++i) {
                for (int j = 0; j < n_features+1; ++j) {
                    delta_W1[i][j] = eta * delta_W1_unscaled[i][j];
                }
            }

            array<array<float, n_hidden+1>, n_output> delta_W2;
            for (int i = 0; i < n_output; ++i) {
                for (int j = 0; j < n_hidden+1; ++j) {
                    delta_W2[i][j] = eta * delta_W2_unscaled[i][j];
                }
            }



            for (int i = 0; i < n_hidden; ++i) {
                for (int j = 0; j < n_features+1; ++j) {
                    w1[i][j] -= delta_W1[i][j];
                }
            }

            for (int i = 0; i < n_output; ++i) {
                for (int j = 0; j < n_hidden+1; ++j) {
                    w2[i][j] -= delta_W2[i][j];
                }
            }
        }

    }
}
// Out:
// Writing train.cpp

// %% [markdown]
// ###Predict

// %%
%%writefile predict.cpp

// Predict the outputs for all the observations in X, where each row of X is a distinct observation.
void MLP_MSELIN_predict(float* x, float* y, int tot_elem) {
    for (int i = 0; i < tot_elem; i += elem) {

        for (int k = 0; k < elem * n_features; ++k) {
            int row = k / n_features;
            int col = k % n_features;
            x_input[row][col] = x[i * n_features + k];
        }

        // Feedforward
        MLP_MSELIN_forward();

        // Copia dei risultati nel vettore y
        copy(rA2[0].begin(), rA2[0].begin() + elem, y + i);
    }
}
// Out:
// Writing predict.cpp

// %% [markdown]
// ###Main

// %%
%%writefile main.cpp
#include "MLP.h"
#include "gen.cpp"
#include "train.cpp"
#include "predict.cpp"

int main() {
    array<array<float, n_features>, num_train> x_train;
    array<float, num_train> y_train;
    sinc2D_gen(x_train[0].data(), y_train.data(), num_train);

    array<array<float, n_features>, num_test> x_test;
    array<float, num_test> y_test;
    sinc2D_gen(x_test[0].data(), y_test.data(), num_test);



    // Shuffling training data
    array<int, num_train> shuffled_ind;
    for (int i = 0; i < num_train; ++i) {
        shuffled_ind[i] = i;
    }

    default_random_engine generator(std::time(nullptr));
    shuffle(shuffled_ind.begin(), shuffled_ind.end(), generator);

    array<array<float, n_features>, num_train> x_train_temp;
    array<float, num_train> y_train_temp;

    for (int i = 0; i < num_train; ++i) {
        x_train_temp[i] = x_train[shuffled_ind[i]];
        y_train_temp[i] = y_train[shuffled_ind[i]];
    }

    x_train = x_train_temp;
    y_train = y_train_temp;

    // Learn weights from training data
    MLP_MSELIN_train(x_train, y_train);



    // Predict the outputs for all the observations in X
    array<float, num_train> ytrain_pred;
    MLP_MSELIN_predict(x_train[0].data(), ytrain_pred.data(), num_train);

    array<float, num_test> ytest_pred;
    MLP_MSELIN_predict(x_test[0].data(), ytest_pred.data(), num_test);



    // Compute accuracy (MSE)
    float acc_train = 0.0;
    for (int i = 0; i < y_train.size(); ++i) {
        acc_train += (y_train[i] - ytrain_pred[i])*(y_train[i] - ytrain_pred[i]);
    }
    acc_train /= (2 * y_train.size());
    printf("Training accuracy (MSE): %g\n", acc_train);

    float acc_test = 0.0;
    for (int i = 0; i < y_test.size(); ++i) {
        acc_test += (y_test[i] - ytest_pred[i])*(y_test[i] - ytest_pred[i]);
    }
    acc_test /= (2 * y_test.size());
    printf("Test accuracy: (MSE): %g\n", acc_test);


    return 0;
}
// Out:
// Writing main.cpp

// %% [markdown]
// ###Run

// %%
!rm prog
!g++ -o prog main.cpp
// Out:
// rm: cannot remove 'prog': No such file or directory

// %%
!./prog
// Out:
// Output streaming troncato alle ultime 5000 righe.
// Epoch 334/500, minibatch 0013, Loss (MSE) 0.293741
// Epoch 334/500, minibatch 0014, Loss (MSE) 0.316857
// Epoch 334/500, minibatch 0015, Loss (MSE) 0.281619
// Epoch 334/500, minibatch 0016, Loss (MSE) 0.300112
// Epoch 334/500, minibatch 0017, Loss (MSE) 0.312407
// Epoch 334/500, minibatch 0018, Loss (MSE) 0.30383
// Epoch 334/500, minibatch 0019, Loss (MSE) 0.303908
// Epoch 334/500, minibatch 0020, Loss (MSE) 0.263444
// Epoch 334/500, minibatch 0021, Loss (MSE) 0.308117
// Epoch 334/500, minibatch 0022, Loss (MSE) 0.288284
// Epoch 334/500, minibatch 0023, Loss (MSE) 0.286051
// Epoch 334/500, minibatch 0024, Loss (MSE) 0.288826
// Epoch 334/500, minibatch 0025, Loss (MSE) 0.296634
// Epoch 334/500, minibatch 0026, Loss (MSE) 0.290624
// Epoch 334/500, minibatch 0027, Loss (MSE) 0.298788
// Epoch 334/500, minibatch 0028, Loss (MSE) 0.296662
// Epoch 334/500, minibatch 0029, Loss (MSE) 0.290456
// Epoch 334/500, minibatch 0030, Loss (MSE) 0.300885
// Epoch 335/500, minibatch 0001, Loss (MSE) 0.285696
// Epoch 335/500, minibatch 0002, Loss (MSE) 0.292737
// Epoch 335/500, minibatch 0003, Loss (MSE) 0.302326
// Epoch 335/500, minibatch 0004, Loss (MSE) 0.294424
// Epoch 335/500, minibatch 0005, Loss (MSE) 0.289167
// Epoch 335/500, minibatch 0006, Loss (MSE) 0.308824
// Epoch 335/500, minibatch 0007, Loss (MSE) 0.290335
// Epoch 335/500, minibatch 0008, Loss (MSE) 0.290505
// Epoch 335/500, minibatch 0009, Loss (MSE) 0.284198
// Epoch 335/500, minibatch 0010, Loss (MSE) 0.30751
// Epoch 335/500, minibatch 0011, Loss (MSE) 0.303583
// Epoch 335/500, minibatch 0012, Loss (MSE) 0.291827
// Epoch 335/500, minibatch 0013, Loss (MSE) 0.292908
// Epoch 335/500, minibatch 0014, Loss (MSE) 0.315817
// Epoch 335/500, minibatch 0015, Loss (MSE) 0.280803
// Epoch 335/500, minibatch 0016, Loss (MSE) 0.299197
// Epoch 335/500, minibatch 0017, Loss (MSE) 0.311428
// Epoch 335/500, minibatch 0018, Loss (MSE) 0.302852
// Epoch 335/500, minibatch 0019, Loss (MSE) 0.30302
// Epoch 335/500, minibatch 0020, Loss (MSE) 0.262706
// Epoch 335/500, minibatch 0021, Loss (MSE) 0.307089
// Epoch 335/500, minibatch 0022, Loss (MSE) 0.287406
// Epoch 335/500, minibatch 0023, Loss (MSE) 0.285202
// Epoch 335/500, minibatch 0024, Loss (MSE) 0.288015
// Epoch 335/500, minibatch 0025, Loss (MSE) 0.295709
// Epoch 335/500, minibatch 0026, Loss (MSE) 0.289735
// Epoch 335/500, minibatch 0027, Loss (MSE) 0.297812
// Epoch 335/500, minibatch 0028, Loss (MSE) 0.295888
// Epoch 335/500, minibatch 0029, Loss (MSE) 0.28957
// Epoch 335/500, minibatch 0030, Loss (MSE) 0.299991
// Epoch 336/500, minibatch 0001, Loss (MSE) 0.284803
// Epoch 336/500, minibatch 0002, Loss (MSE) 0.291899
// Epoch 336/500, minibatch 0003, Loss (MSE) 0.301393
// Epoch 336/500, minibatch 0004, Loss (MSE) 0.293553
// Epoch 336/500, minibatch 0005, Loss (MSE) 0.288355
// Epoch 336/500, minibatch 0006, Loss (MSE) 0.307867
// Epoch 336/500, minibatch 0007, Loss (MSE) 0.289453
// Epoch 336/500, minibatch 0008, Loss (MSE) 0.289741
// Epoch 336/500, minibatch 0009, Loss (MSE) 0.283382
// Epoch 336/500, minibatch 0010, Loss (MSE) 0.30653
// Epoch 336/500, minibatch 0011, Loss (MSE) 0.302623
// Epoch 336/500, minibatch 0012, Loss (MSE) 0.290937
// Epoch 336/500, minibatch 0013, Loss (MSE) 0.292084
// Epoch 336/500, minibatch 0014, Loss (MSE) 0.314789
// Epoch 336/500, minibatch 0015, Loss (MSE) 0.279996
// Epoch 336/500, minibatch 0016, Loss (MSE) 0.298292
// Epoch 336/500, minibatch 0017, Loss (MSE) 0.310458
// Epoch 336/500, minibatch 0018, Loss (MSE) 0.301885
// Epoch 336/500, minibatch 0019, Loss (MSE) 0.302141
// Epoch 336/500, minibatch 0020, Loss (MSE) 0.261977
// Epoch 336/500, minibatch 0021, Loss (MSE) 0.306071
// Epoch 336/500, minibatch 0022, Loss (MSE) 0.286538
// Epoch 336/500, minibatch 0023, Loss (MSE) 0.284363
// Epoch 336/500, minibatch 0024, Loss (MSE) 0.287213
// Epoch 336/500, minibatch 0025, Loss (MSE) 0.294793
// Epoch 336/500, minibatch 0026, Loss (MSE) 0.288855
// Epoch 336/500, minibatch 0027, Loss (MSE) 0.296846
// Epoch 336/500, minibatch 0028, Loss (MSE) 0.295123
// Epoch 336/500, minibatch 0029, Loss (MSE) 0.288693
// Epoch 336/500, minibatch 0030, Loss (MSE) 0.299106
// Epoch 337/500, minibatch 0001, Loss (MSE) 0.283919
// Epoch 337/500, minibatch 0002, Loss (MSE) 0.29107
// Epoch 337/500, minibatch 0003, Loss (MSE) 0.30047
// Epoch 337/500, minibatch 0004, Loss (MSE) 0.29269
// Epoch 337/500, minibatch 0005, Loss (MSE) 0.28755
// Epoch 337/500, minibatch 0006, Loss (MSE) 0.30692
// Epoch 337/500, minibatch 0007, Loss (MSE) 0.28858
// Epoch 337/500, minibatch 0008, Loss (MSE) 0.288985
// Epoch 337/500, minibatch 0009, Loss (MSE) 0.282575
// Epoch 337/500, minibatch 0010, Loss (MSE) 0.30556
// Epoch 337/500, minibatch 0011, Loss (MSE) 0.301673
// Epoch 337/500, minibatch 0012, Loss (MSE) 0.290055
// Epoch 337/500, minibatch 0013, Loss (MSE) 0.291269
// Epoch 337/500, minibatch 0014, Loss (MSE) 0.31377
// Epoch 337/500, minibatch 0015, Loss (MSE) 0.279197
// Epoch 337/500, minibatch 0016, Loss (MSE) 0.297396
// Epoch 337/500, minibatch 0017, Loss (MSE) 0.309499
// Epoch 337/500, minibatch 0018, Loss (MSE) 0.300927
// Epoch 337/500, minibatch 0019, Loss (MSE) 0.301272
// Epoch 337/500, minibatch 0020, Loss (MSE) 0.261255
// Epoch 337/500, minibatch 0021, Loss (MSE) 0.305064
// Epoch 337/500, minibatch 0022, Loss (MSE) 0.285679
// Epoch 337/500, minibatch 0023, Loss (MSE) 0.283532
// Epoch 337/500, minibatch 0024, Loss (MSE) 0.286419
// Epoch 337/500, minibatch 0025, Loss (MSE) 0.293886
// Epoch 337/500, minibatch 0026, Loss (MSE) 0.287984
// Epoch 337/500, minibatch 0027, Loss (MSE) 0.295891
// Epoch 337/500, minibatch 0028, Loss (MSE) 0.294365
// Epoch 337/500, minibatch 0029, Loss (MSE) 0.287826
// Epoch 337/500, minibatch 0030, Loss (MSE) 0.298231
// Epoch 338/500, minibatch 0001, Loss (MSE) 0.283044
// Epoch 338/500, minibatch 0002, Loss (MSE) 0.29025
// Epoch 338/500, minibatch 0003, Loss (MSE) 0.299557
// Epoch 338/500, minibatch 0004, Loss (MSE) 0.291837
// Epoch 338/500, minibatch 0005, Loss (MSE) 0.286754
// Epoch 338/500, minibatch 0006, Loss (MSE) 0.305984
// Epoch 338/500, minibatch 0007, Loss (MSE) 0.287716
// Epoch 338/500, minibatch 0008, Loss (MSE) 0.288237
// Epoch 338/500, minibatch 0009, Loss (MSE) 0.281776
// Epoch 338/500, minibatch 0010, Loss (MSE) 0.3046
// Epoch 338/500, minibatch 0011, Loss (MSE) 0.300733
// Epoch 338/500, minibatch 0012, Loss (MSE) 0.289182
// Epoch 338/500, minibatch 0013, Loss (MSE) 0.290462
// Epoch 338/500, minibatch 0014, Loss (MSE) 0.312762
// Epoch 338/500, minibatch 0015, Loss (MSE) 0.278407
// Epoch 338/500, minibatch 0016, Loss (MSE) 0.296509
// Epoch 338/500, minibatch 0017, Loss (MSE) 0.308548
// Epoch 338/500, minibatch 0018, Loss (MSE) 0.299979
// Epoch 338/500, minibatch 0019, Loss (MSE) 0.300412
// Epoch 338/500, minibatch 0020, Loss (MSE) 0.260541
// Epoch 338/500, minibatch 0021, Loss (MSE) 0.304067
// Epoch 338/500, minibatch 0022, Loss (MSE) 0.284828
// Epoch 338/500, minibatch 0023, Loss (MSE) 0.282711
// Epoch 338/500, minibatch 0024, Loss (MSE) 0.285634
// Epoch 338/500, minibatch 0025, Loss (MSE) 0.292988
// Epoch 338/500, minibatch 0026, Loss (MSE) 0.287121
// Epoch 338/500, minibatch 0027, Loss (MSE) 0.294945
// Epoch 338/500, minibatch 0028, Loss (MSE) 0.293616
// Epoch 338/500, minibatch 0029, Loss (MSE) 0.286967
// Epoch 338/500, minibatch 0030, Loss (MSE) 0.297365
// Epoch 339/500, minibatch 0001, Loss (MSE) 0.282177
// Epoch 339/500, minibatch 0002, Loss (MSE) 0.289438
// Epoch 339/500, minibatch 0003, Loss (MSE) 0.298654
// Epoch 339/500, minibatch 0004, Loss (MSE) 0.290993
// Epoch 339/500, minibatch 0005, Loss (MSE) 0.285966
// Epoch 339/500, minibatch 0006, Loss (MSE) 0.305057
// Epoch 339/500, minibatch 0007, Loss (MSE) 0.28686
// Epoch 339/500, minibatch 0008, Loss (MSE) 0.287497
// Epoch 339/500, minibatch 0009, Loss (MSE) 0.280986
// Epoch 339/500, minibatch 0010, Loss (MSE) 0.30365
// Epoch 339/500, minibatch 0011, Loss (MSE) 0.299802
// Epoch 339/500, minibatch 0012, Loss (MSE) 0.288318
// Epoch 339/500, minibatch 0013, Loss (MSE) 0.289665
// Epoch 339/500, minibatch 0014, Loss (MSE) 0.311765
// Epoch 339/500, minibatch 0015, Loss (MSE) 0.277625
// Epoch 339/500, minibatch 0016, Loss (MSE) 0.295631
// Epoch 339/500, minibatch 0017, Loss (MSE) 0.307608
// Epoch 339/500, minibatch 0018, Loss (MSE) 0.299042
// Epoch 339/500, minibatch 0019, Loss (MSE) 0.299561
// Epoch 339/500, minibatch 0020, Loss (MSE) 0.259835
// Epoch 339/500, minibatch 0021, Loss (MSE) 0.303079
// Epoch 339/500, minibatch 0022, Loss (MSE) 0.283987
// Epoch 339/500, minibatch 0023, Loss (MSE) 0.281897
// Epoch 339/500, minibatch 0024, Loss (MSE) 0.284856
// Epoch 339/500, minibatch 0025, Loss (MSE) 0.2921
// Epoch 339/500, minibatch 0026, Loss (MSE) 0.286268
// Epoch 339/500, minibatch 0027, Loss (MSE) 0.294009
// Epoch 339/500, minibatch 0028, Loss (MSE) 0.292874
// Epoch 339/500, minibatch 0029, Loss (MSE) 0.286116
// Epoch 339/500, minibatch 0030, Loss (MSE) 0.296508
// Epoch 340/500, minibatch 0001, Loss (MSE) 0.28132
// Epoch 340/500, minibatch 0002, Loss (MSE) 0.288636
// Epoch 340/500, minibatch 0003, Loss (MSE) 0.29776
// Epoch 340/500, minibatch 0004, Loss (MSE) 0.290158
// Epoch 340/500, minibatch 0005, Loss (MSE) 0.285187
// Epoch 340/500, minibatch 0006, Loss (MSE) 0.304139
// Epoch 340/500, minibatch 0007, Loss (MSE) 0.286014
// Epoch 340/500, minibatch 0008, Loss (MSE) 0.286765
// Epoch 340/500, minibatch 0009, Loss (MSE) 0.280204
// Epoch 340/500, minibatch 0010, Loss (MSE) 0.30271
// Epoch 340/500, minibatch 0011, Loss (MSE) 0.298881
// Epoch 340/500, minibatch 0012, Loss (MSE) 0.287463
// Epoch 340/500, minibatch 0013, Loss (MSE) 0.288875
// Epoch 340/500, minibatch 0014, Loss (MSE) 0.310777
// Epoch 340/500, minibatch 0015, Loss (MSE) 0.276852
// Epoch 340/500, minibatch 0016, Loss (MSE) 0.294762
// Epoch 340/500, minibatch 0017, Loss (MSE) 0.306676
// Epoch 340/500, minibatch 0018, Loss (MSE) 0.298113
// Epoch 340/500, minibatch 0019, Loss (MSE) 0.298719
// Epoch 340/500, minibatch 0020, Loss (MSE) 0.259137
// Epoch 340/500, minibatch 0021, Loss (MSE) 0.302102
// Epoch 340/500, minibatch 0022, Loss (MSE) 0.283154
// Epoch 340/500, minibatch 0023, Loss (MSE) 0.281092
// Epoch 340/500, minibatch 0024, Loss (MSE) 0.284087
// Epoch 340/500, minibatch 0025, Loss (MSE) 0.29122
// Epoch 340/500, minibatch 0026, Loss (MSE) 0.285423
// Epoch 340/500, minibatch 0027, Loss (MSE) 0.293083
// Epoch 340/500, minibatch 0028, Loss (MSE) 0.29214
// Epoch 340/500, minibatch 0029, Loss (MSE) 0.285275
// Epoch 340/500, minibatch 0030, Loss (MSE) 0.295659
// Epoch 341/500, minibatch 0001, Loss (MSE) 0.280472
// Epoch 341/500, minibatch 0002, Loss (MSE) 0.287841
// Epoch 341/500, minibatch 0003, Loss (MSE) 0.296875
// Epoch 341/500, minibatch 0004, Loss (MSE) 0.289331
// Epoch 341/500, minibatch 0005, Loss (MSE) 0.284415
// Epoch 341/500, minibatch 0006, Loss (MSE) 0.303232
// Epoch 341/500, minibatch 0007, Loss (MSE) 0.285176
// Epoch 341/500, minibatch 0008, Loss (MSE) 0.28604
// Epoch 341/500, minibatch 0009, Loss (MSE) 0.279431
// Epoch 341/500, minibatch 0010, Loss (MSE) 0.30178
// Epoch 341/500, minibatch 0011, Loss (MSE) 0.297969
// Epoch 341/500, minibatch 0012, Loss (MSE) 0.286616
// Epoch 341/500, minibatch 0013, Loss (MSE) 0.288094
// Epoch 341/500, minibatch 0014, Loss (MSE) 0.3098
// Epoch 341/500, minibatch 0015, Loss (MSE) 0.276086
// Epoch 341/500, minibatch 0016, Loss (MSE) 0.293902
// Epoch 341/500, minibatch 0017, Loss (MSE) 0.305753
// Epoch 341/500, minibatch 0018, Loss (MSE) 0.297195
// Epoch 341/500, minibatch 0019, Loss (MSE) 0.297886
// Epoch 341/500, minibatch 0020, Loss (MSE) 0.258446
// Epoch 341/500, minibatch 0021, Loss (MSE) 0.301135
// Epoch 341/500, minibatch 0022, Loss (MSE) 0.28233
// Epoch 341/500, minibatch 0023, Loss (MSE) 0.280296
// Epoch 341/500, minibatch 0024, Loss (MSE) 0.283326
// Epoch 341/500, minibatch 0025, Loss (MSE) 0.29035
// Epoch 341/500, minibatch 0026, Loss (MSE) 0.284587
// Epoch 341/500, minibatch 0027, Loss (MSE) 0.292166
// Epoch 341/500, minibatch 0028, Loss (MSE) 0.291415
// Epoch 341/500, minibatch 0029, Loss (MSE) 0.284442
// Epoch 341/500, minibatch 0030, Loss (MSE) 0.29482
// Epoch 342/500, minibatch 0001, Loss (MSE) 0.279632
// Epoch 342/500, minibatch 0002, Loss (MSE) 0.287056
// Epoch 342/500, minibatch 0003, Loss (MSE) 0.296
// Epoch 342/500, minibatch 0004, Loss (MSE) 0.288514
// Epoch 342/500, minibatch 0005, Loss (MSE) 0.283651
// Epoch 342/500, minibatch 0006, Loss (MSE) 0.302334
// Epoch 342/500, minibatch 0007, Loss (MSE) 0.284346
// Epoch 342/500, minibatch 0008, Loss (MSE) 0.285323
// Epoch 342/500, minibatch 0009, Loss (MSE) 0.278665
// Epoch 342/500, minibatch 0010, Loss (MSE) 0.300859
// Epoch 342/500, minibatch 0011, Loss (MSE) 0.297067
// Epoch 342/500, minibatch 0012, Loss (MSE) 0.285777
// Epoch 342/500, minibatch 0013, Loss (MSE) 0.287321
// Epoch 342/500, minibatch 0014, Loss (MSE) 0.308832
// Epoch 342/500, minibatch 0015, Loss (MSE) 0.275329
// Epoch 342/500, minibatch 0016, Loss (MSE) 0.293051
// Epoch 342/500, minibatch 0017, Loss (MSE) 0.30484
// Epoch 342/500, minibatch 0018, Loss (MSE) 0.296285
// Epoch 342/500, minibatch 0019, Loss (MSE) 0.297061
// Epoch 342/500, minibatch 0020, Loss (MSE) 0.257762
// Epoch 342/500, minibatch 0021, Loss (MSE) 0.300177
// Epoch 342/500, minibatch 0022, Loss (MSE) 0.281515
// Epoch 342/500, minibatch 0023, Loss (MSE) 0.279508
// Epoch 342/500, minibatch 0024, Loss (MSE) 0.282573
// Epoch 342/500, minibatch 0025, Loss (MSE) 0.289488
// Epoch 342/500, minibatch 0026, Loss (MSE) 0.283759
// Epoch 342/500, minibatch 0027, Loss (MSE) 0.291259
// Epoch 342/500, minibatch 0028, Loss (MSE) 0.290696
// Epoch 342/500, minibatch 0029, Loss (MSE) 0.283618
// Epoch 342/500, minibatch 0030, Loss (MSE) 0.293989
// Epoch 343/500, minibatch 0001, Loss (MSE) 0.278801
// Epoch 343/500, minibatch 0002, Loss (MSE) 0.286278
// Epoch 343/500, minibatch 0003, Loss (MSE) 0.295134
// Epoch 343/500, minibatch 0004, Loss (MSE) 0.287704
// Epoch 343/500, minibatch 0005, Loss (MSE) 0.282894
// Epoch 343/500, minibatch 0006, Loss (MSE) 0.301446
// Epoch 343/500, minibatch 0007, Loss (MSE) 0.283525
// Epoch 343/500, minibatch 0008, Loss (MSE) 0.284615
// Epoch 343/500, minibatch 0009, Loss (MSE) 0.277908
// Epoch 343/500, minibatch 0010, Loss (MSE) 0.299948
// Epoch 343/500, minibatch 0011, Loss (MSE) 0.296174
// Epoch 343/500, minibatch 0012, Loss (MSE) 0.284948
// Epoch 343/500, minibatch 0013, Loss (MSE) 0.286557
// Epoch 343/500, minibatch 0014, Loss (MSE) 0.307874
// Epoch 343/500, minibatch 0015, Loss (MSE) 0.27458
// Epoch 343/500, minibatch 0016, Loss (MSE) 0.292209
// Epoch 343/500, minibatch 0017, Loss (MSE) 0.303935
// Epoch 343/500, minibatch 0018, Loss (MSE) 0.295385
// Epoch 343/500, minibatch 0019, Loss (MSE) 0.296246
// Epoch 343/500, minibatch 0020, Loss (MSE) 0.257086
// Epoch 343/500, minibatch 0021, Loss (MSE) 0.299228
// Epoch 343/500, minibatch 0022, Loss (MSE) 0.280708
// Epoch 343/500, minibatch 0023, Loss (MSE) 0.278728
// Epoch 343/500, minibatch 0024, Loss (MSE) 0.281828
// Epoch 343/500, minibatch 0025, Loss (MSE) 0.288635
// Epoch 343/500, minibatch 0026, Loss (MSE) 0.282939
// Epoch 343/500, minibatch 0027, Loss (MSE) 0.290362
// Epoch 343/500, minibatch 0028, Loss (MSE) 0.289986
// Epoch 343/500, minibatch 0029, Loss (MSE) 0.282802
// Epoch 343/500, minibatch 0030, Loss (MSE) 0.293166
// Epoch 344/500, minibatch 0001, Loss (MSE) 0.277978
// Epoch 344/500, minibatch 0002, Loss (MSE) 0.285509
// Epoch 344/500, minibatch 0003, Loss (MSE) 0.294276
// Epoch 344/500, minibatch 0004, Loss (MSE) 0.286903
// Epoch 344/500, minibatch 0005, Loss (MSE) 0.282146
// Epoch 344/500, minibatch 0006, Loss (MSE) 0.300566
// Epoch 344/500, minibatch 0007, Loss (MSE) 0.282712
// Epoch 344/500, minibatch 0008, Loss (MSE) 0.283913
// Epoch 344/500, minibatch 0009, Loss (MSE) 0.277159
// Epoch 344/500, minibatch 0010, Loss (MSE) 0.299046
// Epoch 344/500, minibatch 0011, Loss (MSE) 0.29529
// Epoch 344/500, minibatch 0012, Loss (MSE) 0.284126
// Epoch 344/500, minibatch 0013, Loss (MSE) 0.2858
// Epoch 344/500, minibatch 0014, Loss (MSE) 0.306926
// Epoch 344/500, minibatch 0015, Loss (MSE) 0.273839
// Epoch 344/500, minibatch 0016, Loss (MSE) 0.291375
// Epoch 344/500, minibatch 0017, Loss (MSE) 0.30304
// Epoch 344/500, minibatch 0018, Loss (MSE) 0.294495
// Epoch 344/500, minibatch 0019, Loss (MSE) 0.295439
// Epoch 344/500, minibatch 0020, Loss (MSE) 0.256417
// Epoch 344/500, minibatch 0021, Loss (MSE) 0.298289
// Epoch 344/500, minibatch 0022, Loss (MSE) 0.27991
// Epoch 344/500, minibatch 0023, Loss (MSE) 0.277956
// Epoch 344/500, minibatch 0024, Loss (MSE) 0.281091
// Epoch 344/500, minibatch 0025, Loss (MSE) 0.287791
// Epoch 344/500, minibatch 0026, Loss (MSE) 0.282128
// Epoch 344/500, minibatch 0027, Loss (MSE) 0.289474
// Epoch 344/500, minibatch 0028, Loss (MSE) 0.289283
// Epoch 344/500, minibatch 0029, Loss (MSE) 0.281994
// Epoch 344/500, minibatch 0030, Loss (MSE) 0.292352
// Epoch 345/500, minibatch 0001, Loss (MSE) 0.277163
// Epoch 345/500, minibatch 0002, Loss (MSE) 0.284748
// Epoch 345/500, minibatch 0003, Loss (MSE) 0.293428
// Epoch 345/500, minibatch 0004, Loss (MSE) 0.286111
// Epoch 345/500, minibatch 0005, Loss (MSE) 0.281405
// Epoch 345/500, minibatch 0006, Loss (MSE) 0.299697
// Epoch 345/500, minibatch 0007, Loss (MSE) 0.281907
// Epoch 345/500, minibatch 0008, Loss (MSE) 0.283219
// Epoch 345/500, minibatch 0009, Loss (MSE) 0.276417
// Epoch 345/500, minibatch 0010, Loss (MSE) 0.298153
// Epoch 345/500, minibatch 0011, Loss (MSE) 0.294415
// Epoch 345/500, minibatch 0012, Loss (MSE) 0.283313
// Epoch 345/500, minibatch 0013, Loss (MSE) 0.285052
// Epoch 345/500, minibatch 0014, Loss (MSE) 0.305987
// Epoch 345/500, minibatch 0015, Loss (MSE) 0.273106
// Epoch 345/500, minibatch 0016, Loss (MSE) 0.290549
// Epoch 345/500, minibatch 0017, Loss (MSE) 0.302153
// Epoch 345/500, minibatch 0018, Loss (MSE) 0.293613
// Epoch 345/500, minibatch 0019, Loss (MSE) 0.29464
// Epoch 345/500, minibatch 0020, Loss (MSE) 0.255755
// Epoch 345/500, minibatch 0021, Loss (MSE) 0.29736
// Epoch 345/500, minibatch 0022, Loss (MSE) 0.27912
// Epoch 345/500, minibatch 0023, Loss (MSE) 0.277193
// Epoch 345/500, minibatch 0024, Loss (MSE) 0.280361
// Epoch 345/500, minibatch 0025, Loss (MSE) 0.286955
// Epoch 345/500, minibatch 0026, Loss (MSE) 0.281325
// Epoch 345/500, minibatch 0027, Loss (MSE) 0.288595
// Epoch 345/500, minibatch 0028, Loss (MSE) 0.288587
// Epoch 345/500, minibatch 0029, Loss (MSE) 0.281194
// Epoch 345/500, minibatch 0030, Loss (MSE) 0.291547
// Epoch 346/500, minibatch 0001, Loss (MSE) 0.276357
// Epoch 346/500, minibatch 0002, Loss (MSE) 0.283995
// Epoch 346/500, minibatch 0003, Loss (MSE) 0.292589
// Epoch 346/500, minibatch 0004, Loss (MSE) 0.285326
// Epoch 346/500, minibatch 0005, Loss (MSE) 0.280671
// Epoch 346/500, minibatch 0006, Loss (MSE) 0.298836
// Epoch 346/500, minibatch 0007, Loss (MSE) 0.281111
// Epoch 346/500, minibatch 0008, Loss (MSE) 0.282532
// Epoch 346/500, minibatch 0009, Loss (MSE) 0.275683
// Epoch 346/500, minibatch 0010, Loss (MSE) 0.29727
// Epoch 346/500, minibatch 0011, Loss (MSE) 0.293549
// Epoch 346/500, minibatch 0012, Loss (MSE) 0.282508
// Epoch 346/500, minibatch 0013, Loss (MSE) 0.284311
// Epoch 346/500, minibatch 0014, Loss (MSE) 0.305058
// Epoch 346/500, minibatch 0015, Loss (MSE) 0.27238
// Epoch 346/500, minibatch 0016, Loss (MSE) 0.289732
// Epoch 346/500, minibatch 0017, Loss (MSE) 0.301275
// Epoch 346/500, minibatch 0018, Loss (MSE) 0.29274
// Epoch 346/500, minibatch 0019, Loss (MSE) 0.29385
// Epoch 346/500, minibatch 0020, Loss (MSE) 0.255101
// Epoch 346/500, minibatch 0021, Loss (MSE) 0.296439
// Epoch 346/500, minibatch 0022, Loss (MSE) 0.278338
// Epoch 346/500, minibatch 0023, Loss (MSE) 0.276437
// Epoch 346/500, minibatch 0024, Loss (MSE) 0.279639
// Epoch 346/500, minibatch 0025, Loss (MSE) 0.286127
// Epoch 346/500, minibatch 0026, Loss (MSE) 0.280531
// Epoch 346/500, minibatch 0027, Loss (MSE) 0.287725
// Epoch 346/500, minibatch 0028, Loss (MSE) 0.287899
// Epoch 346/500, minibatch 0029, Loss (MSE) 0.280403
// Epoch 346/500, minibatch 0030, Loss (MSE) 0.290749
// Epoch 347/500, minibatch 0001, Loss (MSE) 0.275559
// Epoch 347/500, minibatch 0002, Loss (MSE) 0.28325
// Epoch 347/500, minibatch 0003, Loss (MSE) 0.291758
// Epoch 347/500, minibatch 0004, Loss (MSE) 0.28455
// Epoch 347/500, minibatch 0005, Loss (MSE) 0.279945
// Epoch 347/500, minibatch 0006, Loss (MSE) 0.297984
// Epoch 347/500, minibatch 0007, Loss (MSE) 0.280322
// Epoch 347/500, minibatch 0008, Loss (MSE) 0.281852
// Epoch 347/500, minibatch 0009, Loss (MSE) 0.274957
// Epoch 347/500, minibatch 0010, Loss (MSE) 0.296395
// Epoch 347/500, minibatch 0011, Loss (MSE) 0.292692
// Epoch 347/500, minibatch 0012, Loss (MSE) 0.281711
// Epoch 347/500, minibatch 0013, Loss (MSE) 0.283578
// Epoch 347/500, minibatch 0014, Loss (MSE) 0.304139
// Epoch 347/500, minibatch 0015, Loss (MSE) 0.271662
// Epoch 347/500, minibatch 0016, Loss (MSE) 0.288923
// Epoch 347/500, minibatch 0017, Loss (MSE) 0.300405
// Epoch 347/500, minibatch 0018, Loss (MSE) 0.291876
// Epoch 347/500, minibatch 0019, Loss (MSE) 0.293068
// Epoch 347/500, minibatch 0020, Loss (MSE) 0.254453
// Epoch 347/500, minibatch 0021, Loss (MSE) 0.295528
// Epoch 347/500, minibatch 0022, Loss (MSE) 0.277564
// Epoch 347/500, minibatch 0023, Loss (MSE) 0.275689
// Epoch 347/500, minibatch 0024, Loss (MSE) 0.278924
// Epoch 347/500, minibatch 0025, Loss (MSE) 0.285308
// Epoch 347/500, minibatch 0026, Loss (MSE) 0.279744
// Epoch 347/500, minibatch 0027, Loss (MSE) 0.286864
// Epoch 347/500, minibatch 0028, Loss (MSE) 0.287218
// Epoch 347/500, minibatch 0029, Loss (MSE) 0.279619
// Epoch 347/500, minibatch 0030, Loss (MSE) 0.28996
// Epoch 348/500, minibatch 0001, Loss (MSE) 0.274769
// Epoch 348/500, minibatch 0002, Loss (MSE) 0.282513
// Epoch 348/500, minibatch 0003, Loss (MSE) 0.290936
// Epoch 348/500, minibatch 0004, Loss (MSE) 0.283782
// Epoch 348/500, minibatch 0005, Loss (MSE) 0.279226
// Epoch 348/500, minibatch 0006, Loss (MSE) 0.297141
// Epoch 348/500, minibatch 0007, Loss (MSE) 0.279542
// Epoch 348/500, minibatch 0008, Loss (MSE) 0.28118
// Epoch 348/500, minibatch 0009, Loss (MSE) 0.274238
// Epoch 348/500, minibatch 0010, Loss (MSE) 0.29553
// Epoch 348/500, minibatch 0011, Loss (MSE) 0.291844
// Epoch 348/500, minibatch 0012, Loss (MSE) 0.280921
// Epoch 348/500, minibatch 0013, Loss (MSE) 0.282853
// Epoch 348/500, minibatch 0014, Loss (MSE) 0.303228
// Epoch 348/500, minibatch 0015, Loss (MSE) 0.270952
// Epoch 348/500, minibatch 0016, Loss (MSE) 0.288123
// Epoch 348/500, minibatch 0017, Loss (MSE) 0.299544
// Epoch 348/500, minibatch 0018, Loss (MSE) 0.291021
// Epoch 348/500, minibatch 0019, Loss (MSE) 0.292295
// Epoch 348/500, minibatch 0020, Loss (MSE) 0.253812
// Epoch 348/500, minibatch 0021, Loss (MSE) 0.294626
// Epoch 348/500, minibatch 0022, Loss (MSE) 0.276799
// Epoch 348/500, minibatch 0023, Loss (MSE) 0.274948
// Epoch 348/500, minibatch 0024, Loss (MSE) 0.278217
// Epoch 348/500, minibatch 0025, Loss (MSE) 0.284497
// Epoch 348/500, minibatch 0026, Loss (MSE) 0.278965
// Epoch 348/500, minibatch 0027, Loss (MSE) 0.286012
// Epoch 348/500, minibatch 0028, Loss (MSE) 0.286544
// Epoch 348/500, minibatch 0029, Loss (MSE) 0.278844
// Epoch 348/500, minibatch 0030, Loss (MSE) 0.289179
// Epoch 349/500, minibatch 0001, Loss (MSE) 0.273987
// Epoch 349/500, minibatch 0002, Loss (MSE) 0.281784
// Epoch 349/500, minibatch 0003, Loss (MSE) 0.290122
// Epoch 349/500, minibatch 0004, Loss (MSE) 0.283022
// Epoch 349/500, minibatch 0005, Loss (MSE) 0.278514
// Epoch 349/500, minibatch 0006, Loss (MSE) 0.296307
// Epoch 349/500, minibatch 0007, Loss (MSE) 0.278769
// Epoch 349/500, minibatch 0008, Loss (MSE) 0.280515
// Epoch 349/500, minibatch 0009, Loss (MSE) 0.273527
// Epoch 349/500, minibatch 0010, Loss (MSE) 0.294673
// Epoch 349/500, minibatch 0011, Loss (MSE) 0.291004
// Epoch 349/500, minibatch 0012, Loss (MSE) 0.28014
// Epoch 349/500, minibatch 0013, Loss (MSE) 0.282136
// Epoch 349/500, minibatch 0014, Loss (MSE) 0.302327
// Epoch 349/500, minibatch 0015, Loss (MSE) 0.27025
// Epoch 349/500, minibatch 0016, Loss (MSE) 0.28733
// Epoch 349/500, minibatch 0017, Loss (MSE) 0.298691
// Epoch 349/500, minibatch 0018, Loss (MSE) 0.290175
// Epoch 349/500, minibatch 0019, Loss (MSE) 0.291529
// Epoch 349/500, minibatch 0020, Loss (MSE) 0.253178
// Epoch 349/500, minibatch 0021, Loss (MSE) 0.293733
// Epoch 349/500, minibatch 0022, Loss (MSE) 0.276041
// Epoch 349/500, minibatch 0023, Loss (MSE) 0.274216
// Epoch 349/500, minibatch 0024, Loss (MSE) 0.277517
// Epoch 349/500, minibatch 0025, Loss (MSE) 0.283694
// Epoch 349/500, minibatch 0026, Loss (MSE) 0.278194
// Epoch 349/500, minibatch 0027, Loss (MSE) 0.285168
// Epoch 349/500, minibatch 0028, Loss (MSE) 0.285877
// Epoch 349/500, minibatch 0029, Loss (MSE) 0.278076
// Epoch 349/500, minibatch 0030, Loss (MSE) 0.288406
// Epoch 350/500, minibatch 0001, Loss (MSE) 0.273213
// Epoch 350/500, minibatch 0002, Loss (MSE) 0.281062
// Epoch 350/500, minibatch 0003, Loss (MSE) 0.289317
// Epoch 350/500, minibatch 0004, Loss (MSE) 0.28227
// Epoch 350/500, minibatch 0005, Loss (MSE) 0.277809
// Epoch 350/500, minibatch 0006, Loss (MSE) 0.295482
// Epoch 350/500, minibatch 0007, Loss (MSE) 0.278004
// Epoch 350/500, minibatch 0008, Loss (MSE) 0.279857
// Epoch 350/500, minibatch 0009, Loss (MSE) 0.272823
// Epoch 350/500, minibatch 0010, Loss (MSE) 0.293825
// Epoch 350/500, minibatch 0011, Loss (MSE) 0.290173
// Epoch 350/500, minibatch 0012, Loss (MSE) 0.279367
// Epoch 350/500, minibatch 0013, Loss (MSE) 0.281426
// Epoch 350/500, minibatch 0014, Loss (MSE) 0.301435
// Epoch 350/500, minibatch 0015, Loss (MSE) 0.269554
// Epoch 350/500, minibatch 0016, Loss (MSE) 0.286545
// Epoch 350/500, minibatch 0017, Loss (MSE) 0.297847
// Epoch 350/500, minibatch 0018, Loss (MSE) 0.289337
// Epoch 350/500, minibatch 0019, Loss (MSE) 0.290771
// Epoch 350/500, minibatch 0020, Loss (MSE) 0.252551
// Epoch 350/500, minibatch 0021, Loss (MSE) 0.292848
// Epoch 350/500, minibatch 0022, Loss (MSE) 0.275291
// Epoch 350/500, minibatch 0023, Loss (MSE) 0.27349
// Epoch 350/500, minibatch 0024, Loss (MSE) 0.276825
// Epoch 350/500, minibatch 0025, Loss (MSE) 0.282899
// Epoch 350/500, minibatch 0026, Loss (MSE) 0.277431
// Epoch 350/500, minibatch 0027, Loss (MSE) 0.284334
// Epoch 350/500, minibatch 0028, Loss (MSE) 0.285217
// Epoch 350/500, minibatch 0029, Loss (MSE) 0.277316
// Epoch 350/500, minibatch 0030, Loss (MSE) 0.287641
// Epoch 351/500, minibatch 0001, Loss (MSE) 0.272447
// Epoch 351/500, minibatch 0002, Loss (MSE) 0.280348
// Epoch 351/500, minibatch 0003, Loss (MSE) 0.28852
// Epoch 351/500, minibatch 0004, Loss (MSE) 0.281525
// Epoch 351/500, minibatch 0005, Loss (MSE) 0.277112
// Epoch 351/500, minibatch 0006, Loss (MSE) 0.294665
// Epoch 351/500, minibatch 0007, Loss (MSE) 0.277246
// Epoch 351/500, minibatch 0008, Loss (MSE) 0.279205
// Epoch 351/500, minibatch 0009, Loss (MSE) 0.272127
// Epoch 351/500, minibatch 0010, Loss (MSE) 0.292986
// Epoch 351/500, minibatch 0011, Loss (MSE) 0.28935
// Epoch 351/500, minibatch 0012, Loss (MSE) 0.278601
// Epoch 351/500, minibatch 0013, Loss (MSE) 0.280723
// Epoch 351/500, minibatch 0014, Loss (MSE) 0.300551
// Epoch 351/500, minibatch 0015, Loss (MSE) 0.268866
// Epoch 351/500, minibatch 0016, Loss (MSE) 0.285768
// Epoch 351/500, minibatch 0017, Loss (MSE) 0.29701
// Epoch 351/500, minibatch 0018, Loss (MSE) 0.288508
// Epoch 351/500, minibatch 0019, Loss (MSE) 0.290022
// Epoch 351/500, minibatch 0020, Loss (MSE) 0.25193
// Epoch 351/500, minibatch 0021, Loss (MSE) 0.291973
// Epoch 351/500, minibatch 0022, Loss (MSE) 0.274549
// Epoch 351/500, minibatch 0023, Loss (MSE) 0.272773
// Epoch 351/500, minibatch 0024, Loss (MSE) 0.276139
// Epoch 351/500, minibatch 0025, Loss (MSE) 0.282113
// Epoch 351/500, minibatch 0026, Loss (MSE) 0.276675
// Epoch 351/500, minibatch 0027, Loss (MSE) 0.283508
// Epoch 351/500, minibatch 0028, Loss (MSE) 0.284565
// Epoch 351/500, minibatch 0029, Loss (MSE) 0.276564
// Epoch 351/500, minibatch 0030, Loss (MSE) 0.286883
// Epoch 352/500, minibatch 0001, Loss (MSE) 0.271688
// Epoch 352/500, minibatch 0002, Loss (MSE) 0.279641
// Epoch 352/500, minibatch 0003, Loss (MSE) 0.287732
// Epoch 352/500, minibatch 0004, Loss (MSE) 0.280788
// Epoch 352/500, minibatch 0005, Loss (MSE) 0.276421
// Epoch 352/500, minibatch 0006, Loss (MSE) 0.293857
// Epoch 352/500, minibatch 0007, Loss (MSE) 0.276497
// Epoch 352/500, minibatch 0008, Loss (MSE) 0.278561
// Epoch 352/500, minibatch 0009, Loss (MSE) 0.271437
// Epoch 352/500, minibatch 0010, Loss (MSE) 0.292155
// Epoch 352/500, minibatch 0011, Loss (MSE) 0.288535
// Epoch 352/500, minibatch 0012, Loss (MSE) 0.277843
// Epoch 352/500, minibatch 0013, Loss (MSE) 0.280028
// Epoch 352/500, minibatch 0014, Loss (MSE) 0.299677
// Epoch 352/500, minibatch 0015, Loss (MSE) 0.268185
// Epoch 352/500, minibatch 0016, Loss (MSE) 0.284999
// Epoch 352/500, minibatch 0017, Loss (MSE) 0.296182
// Epoch 352/500, minibatch 0018, Loss (MSE) 0.287687
// Epoch 352/500, minibatch 0019, Loss (MSE) 0.28928
// Epoch 352/500, minibatch 0020, Loss (MSE) 0.251316
// Epoch 352/500, minibatch 0021, Loss (MSE) 0.291106
// Epoch 352/500, minibatch 0022, Loss (MSE) 0.273814
// Epoch 352/500, minibatch 0023, Loss (MSE) 0.272063
// Epoch 352/500, minibatch 0024, Loss (MSE) 0.275461
// Epoch 352/500, minibatch 0025, Loss (MSE) 0.281333
// Epoch 352/500, minibatch 0026, Loss (MSE) 0.275927
// Epoch 352/500, minibatch 0027, Loss (MSE) 0.28269
// Epoch 352/500, minibatch 0028, Loss (MSE) 0.283918
// Epoch 352/500, minibatch 0029, Loss (MSE) 0.275819
// Epoch 352/500, minibatch 0030, Loss (MSE) 0.286134
// Epoch 353/500, minibatch 0001, Loss (MSE) 0.270937
// Epoch 353/500, minibatch 0002, Loss (MSE) 0.278942
// Epoch 353/500, minibatch 0003, Loss (MSE) 0.286951
// Epoch 353/500, minibatch 0004, Loss (MSE) 0.280059
// Epoch 353/500, minibatch 0005, Loss (MSE) 0.275738
// Epoch 353/500, minibatch 0006, Loss (MSE) 0.293058
// Epoch 353/500, minibatch 0007, Loss (MSE) 0.275754
// Epoch 353/500, minibatch 0008, Loss (MSE) 0.277923
// Epoch 353/500, minibatch 0009, Loss (MSE) 0.270755
// Epoch 353/500, minibatch 0010, Loss (MSE) 0.291333
// Epoch 353/500, minibatch 0011, Loss (MSE) 0.287728
// Epoch 353/500, minibatch 0012, Loss (MSE) 0.277092
// Epoch 353/500, minibatch 0013, Loss (MSE) 0.27934
// Epoch 353/500, minibatch 0014, Loss (MSE) 0.298811
// Epoch 353/500, minibatch 0015, Loss (MSE) 0.267512
// Epoch 353/500, minibatch 0016, Loss (MSE) 0.284238
// Epoch 353/500, minibatch 0017, Loss (MSE) 0.295361
// Epoch 353/500, minibatch 0018, Loss (MSE) 0.286874
// Epoch 353/500, minibatch 0019, Loss (MSE) 0.288546
// Epoch 353/500, minibatch 0020, Loss (MSE) 0.250709
// Epoch 353/500, minibatch 0021, Loss (MSE) 0.290247
// Epoch 353/500, minibatch 0022, Loss (MSE) 0.273088
// Epoch 353/500, minibatch 0023, Loss (MSE) 0.27136
// Epoch 353/500, minibatch 0024, Loss (MSE) 0.27479
// Epoch 353/500, minibatch 0025, Loss (MSE) 0.280562
// Epoch 353/500, minibatch 0026, Loss (MSE) 0.275186
// Epoch 353/500, minibatch 0027, Loss (MSE) 0.281881
// Epoch 353/500, minibatch 0028, Loss (MSE) 0.283279
// Epoch 353/500, minibatch 0029, Loss (MSE) 0.275082
// Epoch 353/500, minibatch 0030, Loss (MSE) 0.285391
// Epoch 354/500, minibatch 0001, Loss (MSE) 0.270194
// Epoch 354/500, minibatch 0002, Loss (MSE) 0.27825
// Epoch 354/500, minibatch 0003, Loss (MSE) 0.286179
// Epoch 354/500, minibatch 0004, Loss (MSE) 0.279337
// Epoch 354/500, minibatch 0005, Loss (MSE) 0.275061
// Epoch 354/500, minibatch 0006, Loss (MSE) 0.292266
// Epoch 354/500, minibatch 0007, Loss (MSE) 0.27502
// Epoch 354/500, minibatch 0008, Loss (MSE) 0.277292
// Epoch 354/500, minibatch 0009, Loss (MSE) 0.27008
// Epoch 354/500, minibatch 0010, Loss (MSE) 0.290519
// Epoch 354/500, minibatch 0011, Loss (MSE) 0.28693
// Epoch 354/500, minibatch 0012, Loss (MSE) 0.276349
// Epoch 354/500, minibatch 0013, Loss (MSE) 0.278659
// Epoch 354/500, minibatch 0014, Loss (MSE) 0.297954
// Epoch 354/500, minibatch 0015, Loss (MSE) 0.266845
// Epoch 354/500, minibatch 0016, Loss (MSE) 0.283484
// Epoch 354/500, minibatch 0017, Loss (MSE) 0.294549
// Epoch 354/500, minibatch 0018, Loss (MSE) 0.28607
// Epoch 354/500, minibatch 0019, Loss (MSE) 0.287819
// Epoch 354/500, minibatch 0020, Loss (MSE) 0.250108
// Epoch 354/500, minibatch 0021, Loss (MSE) 0.289397
// Epoch 354/500, minibatch 0022, Loss (MSE) 0.272368
// Epoch 354/500, minibatch 0023, Loss (MSE) 0.270664
// Epoch 354/500, minibatch 0024, Loss (MSE) 0.274125
// Epoch 354/500, minibatch 0025, Loss (MSE) 0.279799
// Epoch 354/500, minibatch 0026, Loss (MSE) 0.274453
// Epoch 354/500, minibatch 0027, Loss (MSE) 0.28108
// Epoch 354/500, minibatch 0028, Loss (MSE) 0.282647
// Epoch 354/500, minibatch 0029, Loss (MSE) 0.274352
// Epoch 354/500, minibatch 0030, Loss (MSE) 0.284657
// Epoch 355/500, minibatch 0001, Loss (MSE) 0.269457
// Epoch 355/500, minibatch 0002, Loss (MSE) 0.277566
// Epoch 355/500, minibatch 0003, Loss (MSE) 0.285414
// Epoch 355/500, minibatch 0004, Loss (MSE) 0.278623
// Epoch 355/500, minibatch 0005, Loss (MSE) 0.274391
// Epoch 355/500, minibatch 0006, Loss (MSE) 0.291483
// Epoch 355/500, minibatch 0007, Loss (MSE) 0.274292
// Epoch 355/500, minibatch 0008, Loss (MSE) 0.276667
// Epoch 355/500, minibatch 0009, Loss (MSE) 0.269412
// Epoch 355/500, minibatch 0010, Loss (MSE) 0.289713
// Epoch 355/500, minibatch 0011, Loss (MSE) 0.28614
// Epoch 355/500, minibatch 0012, Loss (MSE) 0.275613
// Epoch 355/500, minibatch 0013, Loss (MSE) 0.277986
// Epoch 355/500, minibatch 0014, Loss (MSE) 0.297105
// Epoch 355/500, minibatch 0015, Loss (MSE) 0.266185
// Epoch 355/500, minibatch 0016, Loss (MSE) 0.282738
// Epoch 355/500, minibatch 0017, Loss (MSE) 0.293744
// Epoch 355/500, minibatch 0018, Loss (MSE) 0.285273
// Epoch 355/500, minibatch 0019, Loss (MSE) 0.2871
// Epoch 355/500, minibatch 0020, Loss (MSE) 0.249513
// Epoch 355/500, minibatch 0021, Loss (MSE) 0.288556
// Epoch 355/500, minibatch 0022, Loss (MSE) 0.271656
// Epoch 355/500, minibatch 0023, Loss (MSE) 0.269975
// Epoch 355/500, minibatch 0024, Loss (MSE) 0.273468
// Epoch 355/500, minibatch 0025, Loss (MSE) 0.279043
// Epoch 355/500, minibatch 0026, Loss (MSE) 0.273728
// Epoch 355/500, minibatch 0027, Loss (MSE) 0.280287
// Epoch 355/500, minibatch 0028, Loss (MSE) 0.282021
// Epoch 355/500, minibatch 0029, Loss (MSE) 0.273629
// Epoch 355/500, minibatch 0030, Loss (MSE) 0.28393
// Epoch 356/500, minibatch 0001, Loss (MSE) 0.268729
// Epoch 356/500, minibatch 0002, Loss (MSE) 0.276888
// Epoch 356/500, minibatch 0003, Loss (MSE) 0.284658
// Epoch 356/500, minibatch 0004, Loss (MSE) 0.277916
// Epoch 356/500, minibatch 0005, Loss (MSE) 0.273728
// Epoch 356/500, minibatch 0006, Loss (MSE) 0.290708
// Epoch 356/500, minibatch 0007, Loss (MSE) 0.273572
// Epoch 356/500, minibatch 0008, Loss (MSE) 0.276049
// Epoch 356/500, minibatch 0009, Loss (MSE) 0.268751
// Epoch 356/500, minibatch 0010, Loss (MSE) 0.288916
// Epoch 356/500, minibatch 0011, Loss (MSE) 0.285358
// Epoch 356/500, minibatch 0012, Loss (MSE) 0.274884
// Epoch 356/500, minibatch 0013, Loss (MSE) 0.277319
// Epoch 356/500, minibatch 0014, Loss (MSE) 0.296265
// Epoch 356/500, minibatch 0015, Loss (MSE) 0.265533
// Epoch 356/500, minibatch 0016, Loss (MSE) 0.282
// Epoch 356/500, minibatch 0017, Loss (MSE) 0.292948
// Epoch 356/500, minibatch 0018, Loss (MSE) 0.284485
// Epoch 356/500, minibatch 0019, Loss (MSE) 0.286389
// Epoch 356/500, minibatch 0020, Loss (MSE) 0.248924
// Epoch 356/500, minibatch 0021, Loss (MSE) 0.287722
// Epoch 356/500, minibatch 0022, Loss (MSE) 0.270951
// Epoch 356/500, minibatch 0023, Loss (MSE) 0.269294
// Epoch 356/500, minibatch 0024, Loss (MSE) 0.272817
// Epoch 356/500, minibatch 0025, Loss (MSE) 0.278294
// Epoch 356/500, minibatch 0026, Loss (MSE) 0.273009
// Epoch 356/500, minibatch 0027, Loss (MSE) 0.279503
// Epoch 356/500, minibatch 0028, Loss (MSE) 0.281401
// Epoch 356/500, minibatch 0029, Loss (MSE) 0.272913
// Epoch 356/500, minibatch 0030, Loss (MSE) 0.28321
// Epoch 357/500, minibatch 0001, Loss (MSE) 0.268008
// Epoch 357/500, minibatch 0002, Loss (MSE) 0.276218
// Epoch 357/500, minibatch 0003, Loss (MSE) 0.283909
// Epoch 357/500, minibatch 0004, Loss (MSE) 0.277216
// Epoch 357/500, minibatch 0005, Loss (MSE) 0.273071
// Epoch 357/500, minibatch 0006, Loss (MSE) 0.289941
// Epoch 357/500, minibatch 0007, Loss (MSE) 0.272859
// Epoch 357/500, minibatch 0008, Loss (MSE) 0.275438
// Epoch 357/500, minibatch 0009, Loss (MSE) 0.268096
// Epoch 357/500, minibatch 0010, Loss (MSE) 0.288126
// Epoch 357/500, minibatch 0011, Loss (MSE) 0.284583
// Epoch 357/500, minibatch 0012, Loss (MSE) 0.274162
// Epoch 357/500, minibatch 0013, Loss (MSE) 0.276659
// Epoch 357/500, minibatch 0014, Loss (MSE) 0.295434
// Epoch 357/500, minibatch 0015, Loss (MSE) 0.264887
// Epoch 357/500, minibatch 0016, Loss (MSE) 0.281268
// Epoch 357/500, minibatch 0017, Loss (MSE) 0.292158
// Epoch 357/500, minibatch 0018, Loss (MSE) 0.283705
// Epoch 357/500, minibatch 0019, Loss (MSE) 0.285684
// Epoch 357/500, minibatch 0020, Loss (MSE) 0.248342
// Epoch 357/500, minibatch 0021, Loss (MSE) 0.286897
// Epoch 357/500, minibatch 0022, Loss (MSE) 0.270254
// Epoch 357/500, minibatch 0023, Loss (MSE) 0.268619
// Epoch 357/500, minibatch 0024, Loss (MSE) 0.272172
// Epoch 357/500, minibatch 0025, Loss (MSE) 0.277553
// Epoch 357/500, minibatch 0026, Loss (MSE) 0.272297
// Epoch 357/500, minibatch 0027, Loss (MSE) 0.278726
// Epoch 357/500, minibatch 0028, Loss (MSE) 0.280788
// Epoch 357/500, minibatch 0029, Loss (MSE) 0.272205
// Epoch 357/500, minibatch 0030, Loss (MSE) 0.282497
// Epoch 358/500, minibatch 0001, Loss (MSE) 0.267293
// Epoch 358/500, minibatch 0002, Loss (MSE) 0.275554
// Epoch 358/500, minibatch 0003, Loss (MSE) 0.283167
// Epoch 358/500, minibatch 0004, Loss (MSE) 0.276524
// Epoch 358/500, minibatch 0005, Loss (MSE) 0.272421
// Epoch 358/500, minibatch 0006, Loss (MSE) 0.289182
// Epoch 358/500, minibatch 0007, Loss (MSE) 0.272152
// Epoch 358/500, minibatch 0008, Loss (MSE) 0.274832
// Epoch 358/500, minibatch 0009, Loss (MSE) 0.267449
// Epoch 358/500, minibatch 0010, Loss (MSE) 0.287345
// Epoch 358/500, minibatch 0011, Loss (MSE) 0.283817
// Epoch 358/500, minibatch 0012, Loss (MSE) 0.273448
// Epoch 358/500, minibatch 0013, Loss (MSE) 0.276007
// Epoch 358/500, minibatch 0014, Loss (MSE) 0.29461
// Epoch 358/500, minibatch 0015, Loss (MSE) 0.264248
// Epoch 358/500, minibatch 0016, Loss (MSE) 0.280544
// Epoch 358/500, minibatch 0017, Loss (MSE) 0.291377
// Epoch 358/500, minibatch 0018, Loss (MSE) 0.282932
// Epoch 358/500, minibatch 0019, Loss (MSE) 0.284987
// Epoch 358/500, minibatch 0020, Loss (MSE) 0.247766
// Epoch 358/500, minibatch 0021, Loss (MSE) 0.28608
// Epoch 358/500, minibatch 0022, Loss (MSE) 0.269564
// Epoch 358/500, minibatch 0023, Loss (MSE) 0.267951
// Epoch 358/500, minibatch 0024, Loss (MSE) 0.271535
// Epoch 358/500, minibatch 0025, Loss (MSE) 0.276819
// Epoch 358/500, minibatch 0026, Loss (MSE) 0.271593
// Epoch 358/500, minibatch 0027, Loss (MSE) 0.277958
// Epoch 358/500, minibatch 0028, Loss (MSE) 0.280181
// Epoch 358/500, minibatch 0029, Loss (MSE) 0.271504
// Epoch 358/500, minibatch 0030, Loss (MSE) 0.281792
// Epoch 359/500, minibatch 0001, Loss (MSE) 0.266586
// Epoch 359/500, minibatch 0002, Loss (MSE) 0.274898
// Epoch 359/500, minibatch 0003, Loss (MSE) 0.282434
// Epoch 359/500, minibatch 0004, Loss (MSE) 0.275838
// Epoch 359/500, minibatch 0005, Loss (MSE) 0.271777
// Epoch 359/500, minibatch 0006, Loss (MSE) 0.28843
// Epoch 359/500, minibatch 0007, Loss (MSE) 0.271453
// Epoch 359/500, minibatch 0008, Loss (MSE) 0.274233
// Epoch 359/500, minibatch 0009, Loss (MSE) 0.266808
// Epoch 359/500, minibatch 0010, Loss (MSE) 0.286571
// Epoch 359/500, minibatch 0011, Loss (MSE) 0.283057
// Epoch 359/500, minibatch 0012, Loss (MSE) 0.272741
// Epoch 359/500, minibatch 0013, Loss (MSE) 0.275361
// Epoch 359/500, minibatch 0014, Loss (MSE) 0.293795
// Epoch 359/500, minibatch 0015, Loss (MSE) 0.263615
// Epoch 359/500, minibatch 0016, Loss (MSE) 0.279827
// Epoch 359/500, minibatch 0017, Loss (MSE) 0.290603
// Epoch 359/500, minibatch 0018, Loss (MSE) 0.282167
// Epoch 359/500, minibatch 0019, Loss (MSE) 0.284298
// Epoch 359/500, minibatch 0020, Loss (MSE) 0.247196
// Epoch 359/500, minibatch 0021, Loss (MSE) 0.285271
// Epoch 359/500, minibatch 0022, Loss (MSE) 0.26888
// Epoch 359/500, minibatch 0023, Loss (MSE) 0.267291
// Epoch 359/500, minibatch 0024, Loss (MSE) 0.270904
// Epoch 359/500, minibatch 0025, Loss (MSE) 0.276093
// Epoch 359/500, minibatch 0026, Loss (MSE) 0.270896
// Epoch 359/500, minibatch 0027, Loss (MSE) 0.277197
// Epoch 359/500, minibatch 0028, Loss (MSE) 0.279581
// Epoch 359/500, minibatch 0029, Loss (MSE) 0.27081
// Epoch 359/500, minibatch 0030, Loss (MSE) 0.281094
// Epoch 360/500, minibatch 0001, Loss (MSE) 0.265886
// Epoch 360/500, minibatch 0002, Loss (MSE) 0.274248
// Epoch 360/500, minibatch 0003, Loss (MSE) 0.281708
// Epoch 360/500, minibatch 0004, Loss (MSE) 0.275159
// Epoch 360/500, minibatch 0005, Loss (MSE) 0.271139
// Epoch 360/500, minibatch 0006, Loss (MSE) 0.287687
// Epoch 360/500, minibatch 0007, Loss (MSE) 0.270761
// Epoch 360/500, minibatch 0008, Loss (MSE) 0.273641
// Epoch 360/500, minibatch 0009, Loss (MSE) 0.266173
// Epoch 360/500, minibatch 0010, Loss (MSE) 0.285805
// Epoch 360/500, minibatch 0011, Loss (MSE) 0.282306
// Epoch 360/500, minibatch 0012, Loss (MSE) 0.27204
// Epoch 360/500, minibatch 0013, Loss (MSE) 0.274721
// Epoch 360/500, minibatch 0014, Loss (MSE) 0.292988
// Epoch 360/500, minibatch 0015, Loss (MSE) 0.262989
// Epoch 360/500, minibatch 0016, Loss (MSE) 0.279118
// Epoch 360/500, minibatch 0017, Loss (MSE) 0.289836
// Epoch 360/500, minibatch 0018, Loss (MSE) 0.28141
// Epoch 360/500, minibatch 0019, Loss (MSE) 0.283615
// Epoch 360/500, minibatch 0020, Loss (MSE) 0.246632
// Epoch 360/500, minibatch 0021, Loss (MSE) 0.284469
// Epoch 360/500, minibatch 0022, Loss (MSE) 0.268204
// Epoch 360/500, minibatch 0023, Loss (MSE) 0.266636
// Epoch 360/500, minibatch 0024, Loss (MSE) 0.270279
// Epoch 360/500, minibatch 0025, Loss (MSE) 0.275374
// Epoch 360/500, minibatch 0026, Loss (MSE) 0.270205
// Epoch 360/500, minibatch 0027, Loss (MSE) 0.276444
// Epoch 360/500, minibatch 0028, Loss (MSE) 0.278986
// Epoch 360/500, minibatch 0029, Loss (MSE) 0.270122
// Epoch 360/500, minibatch 0030, Loss (MSE) 0.280402
// Epoch 361/500, minibatch 0001, Loss (MSE) 0.265193
// Epoch 361/500, minibatch 0002, Loss (MSE) 0.273605
// Epoch 361/500, minibatch 0003, Loss (MSE) 0.280989
// Epoch 361/500, minibatch 0004, Loss (MSE) 0.274488
// Epoch 361/500, minibatch 0005, Loss (MSE) 0.270508
// Epoch 361/500, minibatch 0006, Loss (MSE) 0.286951
// Epoch 361/500, minibatch 0007, Loss (MSE) 0.270076
// Epoch 361/500, minibatch 0008, Loss (MSE) 0.273054
// Epoch 361/500, minibatch 0009, Loss (MSE) 0.265545
// Epoch 361/500, minibatch 0010, Loss (MSE) 0.285047
// Epoch 361/500, minibatch 0011, Loss (MSE) 0.281562
// Epoch 361/500, minibatch 0012, Loss (MSE) 0.271347
// Epoch 361/500, minibatch 0013, Loss (MSE) 0.274089
// Epoch 361/500, minibatch 0014, Loss (MSE) 0.292188
// Epoch 361/500, minibatch 0015, Loss (MSE) 0.26237
// Epoch 361/500, minibatch 0016, Loss (MSE) 0.278415
// Epoch 361/500, minibatch 0017, Loss (MSE) 0.289076
// Epoch 361/500, minibatch 0018, Loss (MSE) 0.28066
// Epoch 361/500, minibatch 0019, Loss (MSE) 0.282939
// Epoch 361/500, minibatch 0020, Loss (MSE) 0.246074
// Epoch 361/500, minibatch 0021, Loss (MSE) 0.283676
// Epoch 361/500, minibatch 0022, Loss (MSE) 0.267534
// Epoch 361/500, minibatch 0023, Loss (MSE) 0.265989
// Epoch 361/500, minibatch 0024, Loss (MSE) 0.269661
// Epoch 361/500, minibatch 0025, Loss (MSE) 0.274661
// Epoch 361/500, minibatch 0026, Loss (MSE) 0.269521
// Epoch 361/500, minibatch 0027, Loss (MSE) 0.275698
// Epoch 361/500, minibatch 0028, Loss (MSE) 0.278398
// Epoch 361/500, minibatch 0029, Loss (MSE) 0.269441
// Epoch 361/500, minibatch 0030, Loss (MSE) 0.279718
// Epoch 362/500, minibatch 0001, Loss (MSE) 0.264507
// Epoch 362/500, minibatch 0002, Loss (MSE) 0.272969
// Epoch 362/500, minibatch 0003, Loss (MSE) 0.280278
// Epoch 362/500, minibatch 0004, Loss (MSE) 0.273823
// Epoch 362/500, minibatch 0005, Loss (MSE) 0.269883
// Epoch 362/500, minibatch 0006, Loss (MSE) 0.286222
// Epoch 362/500, minibatch 0007, Loss (MSE) 0.269397
// Epoch 362/500, minibatch 0008, Loss (MSE) 0.272473
// Epoch 362/500, minibatch 0009, Loss (MSE) 0.264924
// Epoch 362/500, minibatch 0010, Loss (MSE) 0.284297
// Epoch 362/500, minibatch 0011, Loss (MSE) 0.280826
// Epoch 362/500, minibatch 0012, Loss (MSE) 0.27066
// Epoch 362/500, minibatch 0013, Loss (MSE) 0.273462
// Epoch 362/500, minibatch 0014, Loss (MSE) 0.291397
// Epoch 362/500, minibatch 0015, Loss (MSE) 0.261757
// Epoch 362/500, minibatch 0016, Loss (MSE) 0.277719
// Epoch 362/500, minibatch 0017, Loss (MSE) 0.288324
// Epoch 362/500, minibatch 0018, Loss (MSE) 0.279918
// Epoch 362/500, minibatch 0019, Loss (MSE) 0.282271
// Epoch 362/500, minibatch 0020, Loss (MSE) 0.245521
// Epoch 362/500, minibatch 0021, Loss (MSE) 0.28289
// Epoch 362/500, minibatch 0022, Loss (MSE) 0.266872
// Epoch 362/500, minibatch 0023, Loss (MSE) 0.265348
// Epoch 362/500, minibatch 0024, Loss (MSE) 0.269049
// Epoch 362/500, minibatch 0025, Loss (MSE) 0.273956
// Epoch 362/500, minibatch 0026, Loss (MSE) 0.268844
// Epoch 362/500, minibatch 0027, Loss (MSE) 0.27496
// Epoch 362/500, minibatch 0028, Loss (MSE) 0.277816
// Epoch 362/500, minibatch 0029, Loss (MSE) 0.268768
// Epoch 362/500, minibatch 0030, Loss (MSE) 0.279041
// Epoch 363/500, minibatch 0001, Loss (MSE) 0.263827
// Epoch 363/500, minibatch 0002, Loss (MSE) 0.272339
// Epoch 363/500, minibatch 0003, Loss (MSE) 0.279573
// Epoch 363/500, minibatch 0004, Loss (MSE) 0.273165
// Epoch 363/500, minibatch 0005, Loss (MSE) 0.269264
// Epoch 363/500, minibatch 0006, Loss (MSE) 0.285502
// Epoch 363/500, minibatch 0007, Loss (MSE) 0.268725
// Epoch 363/500, minibatch 0008, Loss (MSE) 0.271899
// Epoch 363/500, minibatch 0009, Loss (MSE) 0.264308
// Epoch 363/500, minibatch 0010, Loss (MSE) 0.283554
// Epoch 363/500, minibatch 0011, Loss (MSE) 0.280096
// Epoch 363/500, minibatch 0012, Loss (MSE) 0.26998
// Epoch 363/500, minibatch 0013, Loss (MSE) 0.272842
// Epoch 363/500, minibatch 0014, Loss (MSE) 0.290614
// Epoch 363/500, minibatch 0015, Loss (MSE) 0.26115
// Epoch 363/500, minibatch 0016, Loss (MSE) 0.27703
// Epoch 363/500, minibatch 0017, Loss (MSE) 0.287579
// Epoch 363/500, minibatch 0018, Loss (MSE) 0.279183
// Epoch 363/500, minibatch 0019, Loss (MSE) 0.281609
// Epoch 363/500, minibatch 0020, Loss (MSE) 0.244975
// Epoch 363/500, minibatch 0021, Loss (MSE) 0.282112
// Epoch 363/500, minibatch 0022, Loss (MSE) 0.266216
// Epoch 363/500, minibatch 0023, Loss (MSE) 0.264713
// Epoch 363/500, minibatch 0024, Loss (MSE) 0.268443
// Epoch 363/500, minibatch 0025, Loss (MSE) 0.273258
// Epoch 363/500, minibatch 0026, Loss (MSE) 0.268174
// Epoch 363/500, minibatch 0027, Loss (MSE) 0.27423
// Epoch 363/500, minibatch 0028, Loss (MSE) 0.27724
// Epoch 363/500, minibatch 0029, Loss (MSE) 0.2681
// Epoch 363/500, minibatch 0030, Loss (MSE) 0.27837
// Epoch 364/500, minibatch 0001, Loss (MSE) 0.263155
// Epoch 364/500, minibatch 0002, Loss (MSE) 0.271716
// Epoch 364/500, minibatch 0003, Loss (MSE) 0.278876
// Epoch 364/500, minibatch 0004, Loss (MSE) 0.272513
// Epoch 364/500, minibatch 0005, Loss (MSE) 0.268652
// Epoch 364/500, minibatch 0006, Loss (MSE) 0.284788
// Epoch 364/500, minibatch 0007, Loss (MSE) 0.26806
// Epoch 364/500, minibatch 0008, Loss (MSE) 0.27133
// Epoch 364/500, minibatch 0009, Loss (MSE) 0.263699
// Epoch 364/500, minibatch 0010, Loss (MSE) 0.282818
// Epoch 364/500, minibatch 0011, Loss (MSE) 0.279374
// Epoch 364/500, minibatch 0012, Loss (MSE) 0.269306
// Epoch 364/500, minibatch 0013, Loss (MSE) 0.272229
// Epoch 364/500, minibatch 0014, Loss (MSE) 0.289838
// Epoch 364/500, minibatch 0015, Loss (MSE) 0.26055
// Epoch 364/500, minibatch 0016, Loss (MSE) 0.276348
// Epoch 364/500, minibatch 0017, Loss (MSE) 0.286841
// Epoch 364/500, minibatch 0018, Loss (MSE) 0.278455
// Epoch 364/500, minibatch 0019, Loss (MSE) 0.280954
// Epoch 364/500, minibatch 0020, Loss (MSE) 0.244434
// Epoch 364/500, minibatch 0021, Loss (MSE) 0.281341
// Epoch 364/500, minibatch 0022, Loss (MSE) 0.265567
// Epoch 364/500, minibatch 0023, Loss (MSE) 0.264085
// Epoch 364/500, minibatch 0024, Loss (MSE) 0.267843
// Epoch 364/500, minibatch 0025, Loss (MSE) 0.272566
// Epoch 364/500, minibatch 0026, Loss (MSE) 0.26751
// Epoch 364/500, minibatch 0027, Loss (MSE) 0.273507
// Epoch 364/500, minibatch 0028, Loss (MSE) 0.27667
// Epoch 364/500, minibatch 0029, Loss (MSE) 0.26744
// Epoch 364/500, minibatch 0030, Loss (MSE) 0.277706
// Epoch 365/500, minibatch 0001, Loss (MSE) 0.262489
// Epoch 365/500, minibatch 0002, Loss (MSE) 0.271099
// Epoch 365/500, minibatch 0003, Loss (MSE) 0.278186
// Epoch 365/500, minibatch 0004, Loss (MSE) 0.271868
// Epoch 365/500, minibatch 0005, Loss (MSE) 0.268045
// Epoch 365/500, minibatch 0006, Loss (MSE) 0.284082
// Epoch 365/500, minibatch 0007, Loss (MSE) 0.267401
// Epoch 365/500, minibatch 0008, Loss (MSE) 0.270767
// Epoch 365/500, minibatch 0009, Loss (MSE) 0.263097
// Epoch 365/500, minibatch 0010, Loss (MSE) 0.28209
// Epoch 365/500, minibatch 0011, Loss (MSE) 0.278659
// Epoch 365/500, minibatch 0012, Loss (MSE) 0.26864
// Epoch 365/500, minibatch 0013, Loss (MSE) 0.271622
// Epoch 365/500, minibatch 0014, Loss (MSE) 0.28907
// Epoch 365/500, minibatch 0015, Loss (MSE) 0.259956
// Epoch 365/500, minibatch 0016, Loss (MSE) 0.275673
// Epoch 365/500, minibatch 0017, Loss (MSE) 0.28611
// Epoch 365/500, minibatch 0018, Loss (MSE) 0.277735
// Epoch 365/500, minibatch 0019, Loss (MSE) 0.280306
// Epoch 365/500, minibatch 0020, Loss (MSE) 0.243899
// Epoch 365/500, minibatch 0021, Loss (MSE) 0.280578
// Epoch 365/500, minibatch 0022, Loss (MSE) 0.264924
// Epoch 365/500, minibatch 0023, Loss (MSE) 0.263463
// Epoch 365/500, minibatch 0024, Loss (MSE) 0.267249
// ...
// Epoch 490/500, minibatch 0019, Loss (MSE) 0.232864
// Epoch 490/500, minibatch 0020, Loss (MSE) 0.205111
// Epoch 490/500, minibatch 0021, Loss (MSE) 0.223632
// Epoch 490/500, minibatch 0022, Loss (MSE) 0.217817
// Epoch 490/500, minibatch 0023, Loss (MSE) 0.217777
// Epoch 490/500, minibatch 0024, Loss (MSE) 0.223493
// Epoch 490/500, minibatch 0025, Loss (MSE) 0.220805
// Epoch 490/500, minibatch 0026, Loss (MSE) 0.217999
// Epoch 490/500, minibatch 0027, Loss (MSE) 0.220455
// Epoch 490/500, minibatch 0028, Loss (MSE) 0.234677
// Epoch 490/500, minibatch 0029, Loss (MSE) 0.218124
// Epoch 490/500, minibatch 0030, Loss (MSE) 0.228469
// Epoch 491/500, minibatch 0001, Loss (MSE) 0.212853
// Epoch 491/500, minibatch 0002, Loss (MSE) 0.226037
// Epoch 491/500, minibatch 0003, Loss (MSE) 0.227486
// Epoch 491/500, minibatch 0004, Loss (MSE) 0.224227
// Epoch 491/500, minibatch 0005, Loss (MSE) 0.222509
// Epoch 491/500, minibatch 0006, Loss (MSE) 0.232447
// Epoch 491/500, minibatch 0007, Loss (MSE) 0.218118
// Epoch 491/500, minibatch 0008, Loss (MSE) 0.229397
// Epoch 491/500, minibatch 0009, Loss (MSE) 0.218682
// Epoch 491/500, minibatch 0010, Loss (MSE) 0.228276
// Epoch 491/500, minibatch 0011, Loss (MSE) 0.225499
// Epoch 491/500, minibatch 0012, Loss (MSE) 0.218666
// Epoch 491/500, minibatch 0013, Loss (MSE) 0.227068
// Epoch 491/500, minibatch 0014, Loss (MSE) 0.231864
// Epoch 491/500, minibatch 0015, Loss (MSE) 0.216659
// Epoch 491/500, minibatch 0016, Loss (MSE) 0.225239
// Epoch 491/500, minibatch 0017, Loss (MSE) 0.230481
// Epoch 491/500, minibatch 0018, Loss (MSE) 0.224148
// Epoch 491/500, minibatch 0019, Loss (MSE) 0.232647
// Epoch 491/500, minibatch 0020, Loss (MSE) 0.204935
// Epoch 491/500, minibatch 0021, Loss (MSE) 0.223369
// Epoch 491/500, minibatch 0022, Loss (MSE) 0.217602
// Epoch 491/500, minibatch 0023, Loss (MSE) 0.217568
// Epoch 491/500, minibatch 0024, Loss (MSE) 0.223291
// Epoch 491/500, minibatch 0025, Loss (MSE) 0.220567
// Epoch 491/500, minibatch 0026, Loss (MSE) 0.217773
// Epoch 491/500, minibatch 0027, Loss (MSE) 0.220219
// Epoch 491/500, minibatch 0028, Loss (MSE) 0.234484
// Epoch 491/500, minibatch 0029, Loss (MSE) 0.217898
// Epoch 491/500, minibatch 0030, Loss (MSE) 0.228245
// Epoch 492/500, minibatch 0001, Loss (MSE) 0.212626
// Epoch 492/500, minibatch 0002, Loss (MSE) 0.225835
// Epoch 492/500, minibatch 0003, Loss (MSE) 0.227258
// Epoch 492/500, minibatch 0004, Loss (MSE) 0.22401
// Epoch 492/500, minibatch 0005, Loss (MSE) 0.222298
// Epoch 492/500, minibatch 0006, Loss (MSE) 0.232217
// Epoch 492/500, minibatch 0007, Loss (MSE) 0.217892
// Epoch 492/500, minibatch 0008, Loss (MSE) 0.229209
// Epoch 492/500, minibatch 0009, Loss (MSE) 0.21848
// Epoch 492/500, minibatch 0010, Loss (MSE) 0.228033
// Epoch 492/500, minibatch 0011, Loss (MSE) 0.225257
// Epoch 492/500, minibatch 0012, Loss (MSE) 0.218436
// Epoch 492/500, minibatch 0013, Loss (MSE) 0.226866
// Epoch 492/500, minibatch 0014, Loss (MSE) 0.231605
// Epoch 492/500, minibatch 0015, Loss (MSE) 0.216466
// Epoch 492/500, minibatch 0016, Loss (MSE) 0.225007
// Epoch 492/500, minibatch 0017, Loss (MSE) 0.23022
// Epoch 492/500, minibatch 0018, Loss (MSE) 0.223904
// Epoch 492/500, minibatch 0019, Loss (MSE) 0.232431
// Epoch 492/500, minibatch 0020, Loss (MSE) 0.204761
// Epoch 492/500, minibatch 0021, Loss (MSE) 0.223108
// Epoch 492/500, minibatch 0022, Loss (MSE) 0.217388
// Epoch 492/500, minibatch 0023, Loss (MSE) 0.21736
// Epoch 492/500, minibatch 0024, Loss (MSE) 0.223089
// Epoch 492/500, minibatch 0025, Loss (MSE) 0.220331
// Epoch 492/500, minibatch 0026, Loss (MSE) 0.217548
// Epoch 492/500, minibatch 0027, Loss (MSE) 0.219985
// Epoch 492/500, minibatch 0028, Loss (MSE) 0.234294
// Epoch 492/500, minibatch 0029, Loss (MSE) 0.217674
// Epoch 492/500, minibatch 0030, Loss (MSE) 0.228022
// Epoch 493/500, minibatch 0001, Loss (MSE) 0.212401
// Epoch 493/500, minibatch 0002, Loss (MSE) 0.225634
// Epoch 493/500, minibatch 0003, Loss (MSE) 0.227033
// Epoch 493/500, minibatch 0004, Loss (MSE) 0.223795
// Epoch 493/500, minibatch 0005, Loss (MSE) 0.222089
// Epoch 493/500, minibatch 0006, Loss (MSE) 0.231988
// Epoch 493/500, minibatch 0007, Loss (MSE) 0.217667
// Epoch 493/500, minibatch 0008, Loss (MSE) 0.229022
// Epoch 493/500, minibatch 0009, Loss (MSE) 0.21828
// Epoch 493/500, minibatch 0010, Loss (MSE) 0.227793
// Epoch 493/500, minibatch 0011, Loss (MSE) 0.225017
// Epoch 493/500, minibatch 0012, Loss (MSE) 0.218209
// Epoch 493/500, minibatch 0013, Loss (MSE) 0.226666
// Epoch 493/500, minibatch 0014, Loss (MSE) 0.231348
// Epoch 493/500, minibatch 0015, Loss (MSE) 0.216275
// Epoch 493/500, minibatch 0016, Loss (MSE) 0.224778
// Epoch 493/500, minibatch 0017, Loss (MSE) 0.229961
// Epoch 493/500, minibatch 0018, Loss (MSE) 0.223661
// Epoch 493/500, minibatch 0019, Loss (MSE) 0.232217
// Epoch 493/500, minibatch 0020, Loss (MSE) 0.204587
// Epoch 493/500, minibatch 0021, Loss (MSE) 0.222848
// Epoch 493/500, minibatch 0022, Loss (MSE) 0.217176
// Epoch 493/500, minibatch 0023, Loss (MSE) 0.217153
// Epoch 493/500, minibatch 0024, Loss (MSE) 0.222889
// Epoch 493/500, minibatch 0025, Loss (MSE) 0.220096
// Epoch 493/500, minibatch 0026, Loss (MSE) 0.217325
// Epoch 493/500, minibatch 0027, Loss (MSE) 0.219752
// Epoch 493/500, minibatch 0028, Loss (MSE) 0.234104
// Epoch 493/500, minibatch 0029, Loss (MSE) 0.217451
// Epoch 493/500, minibatch 0030, Loss (MSE) 0.227801
// Epoch 494/500, minibatch 0001, Loss (MSE) 0.212178
// Epoch 494/500, minibatch 0002, Loss (MSE) 0.225435
// Epoch 494/500, minibatch 0003, Loss (MSE) 0.226808
// Epoch 494/500, minibatch 0004, Loss (MSE) 0.223581
// Epoch 494/500, minibatch 0005, Loss (MSE) 0.22188
// Epoch 494/500, minibatch 0006, Loss (MSE) 0.231761
// Epoch 494/500, minibatch 0007, Loss (MSE) 0.217444
// Epoch 494/500, minibatch 0008, Loss (MSE) 0.228836
// Epoch 494/500, minibatch 0009, Loss (MSE) 0.218081
// Epoch 494/500, minibatch 0010, Loss (MSE) 0.227554
// Epoch 494/500, minibatch 0011, Loss (MSE) 0.224778
// Epoch 494/500, minibatch 0012, Loss (MSE) 0.217982
// Epoch 494/500, minibatch 0013, Loss (MSE) 0.226467
// Epoch 494/500, minibatch 0014, Loss (MSE) 0.231092
// Epoch 494/500, minibatch 0015, Loss (MSE) 0.216084
// Epoch 494/500, minibatch 0016, Loss (MSE) 0.224549
// Epoch 494/500, minibatch 0017, Loss (MSE) 0.229704
// Epoch 494/500, minibatch 0018, Loss (MSE) 0.22342
// Epoch 494/500, minibatch 0019, Loss (MSE) 0.232004
// Epoch 494/500, minibatch 0020, Loss (MSE) 0.204415
// Epoch 494/500, minibatch 0021, Loss (MSE) 0.222591
// Epoch 494/500, minibatch 0022, Loss (MSE) 0.216966
// Epoch 494/500, minibatch 0023, Loss (MSE) 0.216948
// Epoch 494/500, minibatch 0024, Loss (MSE) 0.22269
// Epoch 494/500, minibatch 0025, Loss (MSE) 0.219863
// Epoch 494/500, minibatch 0026, Loss (MSE) 0.217103
// Epoch 494/500, minibatch 0027, Loss (MSE) 0.21952
// Epoch 494/500, minibatch 0028, Loss (MSE) 0.233915
// Epoch 494/500, minibatch 0029, Loss (MSE) 0.217229
// Epoch 494/500, minibatch 0030, Loss (MSE) 0.227581
// Epoch 495/500, minibatch 0001, Loss (MSE) 0.211956
// Epoch 495/500, minibatch 0002, Loss (MSE) 0.225237
// Epoch 495/500, minibatch 0003, Loss (MSE) 0.226585
// Epoch 495/500, minibatch 0004, Loss (MSE) 0.223368
// Epoch 495/500, minibatch 0005, Loss (MSE) 0.221674
// Epoch 495/500, minibatch 0006, Loss (MSE) 0.231535
// Epoch 495/500, minibatch 0007, Loss (MSE) 0.217222
// Epoch 495/500, minibatch 0008, Loss (MSE) 0.228651
// Epoch 495/500, minibatch 0009, Loss (MSE) 0.217884
// Epoch 495/500, minibatch 0010, Loss (MSE) 0.227317
// Epoch 495/500, minibatch 0011, Loss (MSE) 0.224541
// Epoch 495/500, minibatch 0012, Loss (MSE) 0.217758
// Epoch 495/500, minibatch 0013, Loss (MSE) 0.226269
// Epoch 495/500, minibatch 0014, Loss (MSE) 0.230838
// Epoch 495/500, minibatch 0015, Loss (MSE) 0.215895
// Epoch 495/500, minibatch 0016, Loss (MSE) 0.224323
// Epoch 495/500, minibatch 0017, Loss (MSE) 0.229449
// Epoch 495/500, minibatch 0018, Loss (MSE) 0.223181
// Epoch 495/500, minibatch 0019, Loss (MSE) 0.231793
// Epoch 495/500, minibatch 0020, Loss (MSE) 0.204244
// Epoch 495/500, minibatch 0021, Loss (MSE) 0.222335
// Epoch 495/500, minibatch 0022, Loss (MSE) 0.216756
// Epoch 495/500, minibatch 0023, Loss (MSE) 0.216744
// Epoch 495/500, minibatch 0024, Loss (MSE) 0.222493
// Epoch 495/500, minibatch 0025, Loss (MSE) 0.219631
// Epoch 495/500, minibatch 0026, Loss (MSE) 0.216883
// Epoch 495/500, minibatch 0027, Loss (MSE) 0.219291
// Epoch 495/500, minibatch 0028, Loss (MSE) 0.233728
// Epoch 495/500, minibatch 0029, Loss (MSE) 0.217009
// Epoch 495/500, minibatch 0030, Loss (MSE) 0.227363
// Epoch 496/500, minibatch 0001, Loss (MSE) 0.211736
// Epoch 496/500, minibatch 0002, Loss (MSE) 0.22504
// Epoch 496/500, minibatch 0003, Loss (MSE) 0.226364
// Epoch 496/500, minibatch 0004, Loss (MSE) 0.223157
// Epoch 496/500, minibatch 0005, Loss (MSE) 0.221468
// Epoch 496/500, minibatch 0006, Loss (MSE) 0.231311
// Epoch 496/500, minibatch 0007, Loss (MSE) 0.217002
// Epoch 496/500, minibatch 0008, Loss (MSE) 0.228467
// Epoch 496/500, minibatch 0009, Loss (MSE) 0.217688
// Epoch 496/500, minibatch 0010, Loss (MSE) 0.227081
// Epoch 496/500, minibatch 0011, Loss (MSE) 0.224305
// Epoch 496/500, minibatch 0012, Loss (MSE) 0.217535
// Epoch 496/500, minibatch 0013, Loss (MSE) 0.226073
// Epoch 496/500, minibatch 0014, Loss (MSE) 0.230586
// Epoch 496/500, minibatch 0015, Loss (MSE) 0.215707
// Epoch 496/500, minibatch 0016, Loss (MSE) 0.224097
// Epoch 496/500, minibatch 0017, Loss (MSE) 0.229195
// Epoch 496/500, minibatch 0018, Loss (MSE) 0.222943
// Epoch 496/500, minibatch 0019, Loss (MSE) 0.231583
// Epoch 496/500, minibatch 0020, Loss (MSE) 0.204074
// Epoch 496/500, minibatch 0021, Loss (MSE) 0.222081
// Epoch 496/500, minibatch 0022, Loss (MSE) 0.216548
// Epoch 496/500, minibatch 0023, Loss (MSE) 0.216541
// Epoch 496/500, minibatch 0024, Loss (MSE) 0.222296
// Epoch 496/500, minibatch 0025, Loss (MSE) 0.219401
// Epoch 496/500, minibatch 0026, Loss (MSE) 0.216664
// Epoch 496/500, minibatch 0027, Loss (MSE) 0.219063
// Epoch 496/500, minibatch 0028, Loss (MSE) 0.233542
// Epoch 496/500, minibatch 0029, Loss (MSE) 0.216791
// Epoch 496/500, minibatch 0030, Loss (MSE) 0.227146
// Epoch 497/500, minibatch 0001, Loss (MSE) 0.211517
// Epoch 497/500, minibatch 0002, Loss (MSE) 0.224845
// Epoch 497/500, minibatch 0003, Loss (MSE) 0.226144
// Epoch 497/500, minibatch 0004, Loss (MSE) 0.222948
// Epoch 497/500, minibatch 0005, Loss (MSE) 0.221263
// Epoch 497/500, minibatch 0006, Loss (MSE) 0.231089
// Epoch 497/500, minibatch 0007, Loss (MSE) 0.216783
// Epoch 497/500, minibatch 0008, Loss (MSE) 0.228285
// Epoch 497/500, minibatch 0009, Loss (MSE) 0.217493
// Epoch 497/500, minibatch 0010, Loss (MSE) 0.226847
// Epoch 497/500, minibatch 0011, Loss (MSE) 0.224072
// Epoch 497/500, minibatch 0012, Loss (MSE) 0.217313
// Epoch 497/500, minibatch 0013, Loss (MSE) 0.225878
// Epoch 497/500, minibatch 0014, Loss (MSE) 0.230335
// Epoch 497/500, minibatch 0015, Loss (MSE) 0.215521
// Epoch 497/500, minibatch 0016, Loss (MSE) 0.223874
// Epoch 497/500, minibatch 0017, Loss (MSE) 0.228943
// Epoch 497/500, minibatch 0018, Loss (MSE) 0.222707
// Epoch 497/500, minibatch 0019, Loss (MSE) 0.231374
// Epoch 497/500, minibatch 0020, Loss (MSE) 0.203905
// Epoch 497/500, minibatch 0021, Loss (MSE) 0.221828
// Epoch 497/500, minibatch 0022, Loss (MSE) 0.216342
// Epoch 497/500, minibatch 0023, Loss (MSE) 0.21634
// Epoch 497/500, minibatch 0024, Loss (MSE) 0.222101
// Epoch 497/500, minibatch 0025, Loss (MSE) 0.219172
// Epoch 497/500, minibatch 0026, Loss (MSE) 0.216447
// Epoch 497/500, minibatch 0027, Loss (MSE) 0.218836
// Epoch 497/500, minibatch 0028, Loss (MSE) 0.233357
// Epoch 497/500, minibatch 0029, Loss (MSE) 0.216574
// Epoch 497/500, minibatch 0030, Loss (MSE) 0.22693
// Epoch 498/500, minibatch 0001, Loss (MSE) 0.2113
// Epoch 498/500, minibatch 0002, Loss (MSE) 0.224651
// Epoch 498/500, minibatch 0003, Loss (MSE) 0.225926
// Epoch 498/500, minibatch 0004, Loss (MSE) 0.222739
// Epoch 498/500, minibatch 0005, Loss (MSE) 0.22106
// Epoch 498/500, minibatch 0006, Loss (MSE) 0.230867
// Epoch 498/500, minibatch 0007, Loss (MSE) 0.216566
// Epoch 498/500, minibatch 0008, Loss (MSE) 0.228103
// Epoch 498/500, minibatch 0009, Loss (MSE) 0.217299
// Epoch 498/500, minibatch 0010, Loss (MSE) 0.226614
// Epoch 498/500, minibatch 0011, Loss (MSE) 0.223839
// Epoch 498/500, minibatch 0012, Loss (MSE) 0.217092
// Epoch 498/500, minibatch 0013, Loss (MSE) 0.225684
// Epoch 498/500, minibatch 0014, Loss (MSE) 0.230086
// Epoch 498/500, minibatch 0015, Loss (MSE) 0.215335
// Epoch 498/500, minibatch 0016, Loss (MSE) 0.223651
// Epoch 498/500, minibatch 0017, Loss (MSE) 0.228692
// Epoch 498/500, minibatch 0018, Loss (MSE) 0.222472
// Epoch 498/500, minibatch 0019, Loss (MSE) 0.231167
// Epoch 498/500, minibatch 0020, Loss (MSE) 0.203737
// Epoch 498/500, minibatch 0021, Loss (MSE) 0.221577
// Epoch 498/500, minibatch 0022, Loss (MSE) 0.216137
// Epoch 498/500, minibatch 0023, Loss (MSE) 0.21614
// Epoch 498/500, minibatch 0024, Loss (MSE) 0.221907
// Epoch 498/500, minibatch 0025, Loss (MSE) 0.218945
// Epoch 498/500, minibatch 0026, Loss (MSE) 0.216231
// Epoch 498/500, minibatch 0027, Loss (MSE) 0.218611
// Epoch 498/500, minibatch 0028, Loss (MSE) 0.233173
// Epoch 498/500, minibatch 0029, Loss (MSE) 0.216358
// Epoch 498/500, minibatch 0030, Loss (MSE) 0.226716
// Epoch 499/500, minibatch 0001, Loss (MSE) 0.211084
// Epoch 499/500, minibatch 0002, Loss (MSE) 0.224458
// Epoch 499/500, minibatch 0003, Loss (MSE) 0.225709
// Epoch 499/500, minibatch 0004, Loss (MSE) 0.222532
// Epoch 499/500, minibatch 0005, Loss (MSE) 0.220859
// Epoch 499/500, minibatch 0006, Loss (MSE) 0.230648
// Epoch 499/500, minibatch 0007, Loss (MSE) 0.21635
// Epoch 499/500, minibatch 0008, Loss (MSE) 0.227923
// Epoch 499/500, minibatch 0009, Loss (MSE) 0.217107
// Epoch 499/500, minibatch 0010, Loss (MSE) 0.226383
// Epoch 499/500, minibatch 0011, Loss (MSE) 0.223608
// Epoch 499/500, minibatch 0012, Loss (MSE) 0.216873
// Epoch 499/500, minibatch 0013, Loss (MSE) 0.225491
// Epoch 499/500, minibatch 0014, Loss (MSE) 0.229839
// Epoch 499/500, minibatch 0015, Loss (MSE) 0.215151
// Epoch 499/500, minibatch 0016, Loss (MSE) 0.22343
// Epoch 499/500, minibatch 0017, Loss (MSE) 0.228443
// Epoch 499/500, minibatch 0018, Loss (MSE) 0.222239
// Epoch 499/500, minibatch 0019, Loss (MSE) 0.230961
// Epoch 499/500, minibatch 0020, Loss (MSE) 0.203571
// Epoch 499/500, minibatch 0021, Loss (MSE) 0.221328
// Epoch 499/500, minibatch 0022, Loss (MSE) 0.215933
// Epoch 499/500, minibatch 0023, Loss (MSE) 0.215942
// Epoch 499/500, minibatch 0024, Loss (MSE) 0.221715
// Epoch 499/500, minibatch 0025, Loss (MSE) 0.218719
// Epoch 499/500, minibatch 0026, Loss (MSE) 0.216017
// Epoch 499/500, minibatch 0027, Loss (MSE) 0.218388
// Epoch 499/500, minibatch 0028, Loss (MSE) 0.23299
// Epoch 499/500, minibatch 0029, Loss (MSE) 0.216143
// Epoch 499/500, minibatch 0030, Loss (MSE) 0.226504
// Epoch 500/500, minibatch 0001, Loss (MSE) 0.210869
// Epoch 500/500, minibatch 0002, Loss (MSE) 0.224266
// Epoch 500/500, minibatch 0003, Loss (MSE) 0.225493
// Epoch 500/500, minibatch 0004, Loss (MSE) 0.222326
// Epoch 500/500, minibatch 0005, Loss (MSE) 0.220658
// Epoch 500/500, minibatch 0006, Loss (MSE) 0.23043
// Epoch 500/500, minibatch 0007, Loss (MSE) 0.216135
// Epoch 500/500, minibatch 0008, Loss (MSE) 0.227744
// Epoch 500/500, minibatch 0009, Loss (MSE) 0.216915
// Epoch 500/500, minibatch 0010, Loss (MSE) 0.226154
// Epoch 500/500, minibatch 0011, Loss (MSE) 0.223379
// Epoch 500/500, minibatch 0012, Loss (MSE) 0.216656
// Epoch 500/500, minibatch 0013, Loss (MSE) 0.2253
// Epoch 500/500, minibatch 0014, Loss (MSE) 0.229594
// Epoch 500/500, minibatch 0015, Loss (MSE) 0.214968
// Epoch 500/500, minibatch 0016, Loss (MSE) 0.223211
// Epoch 500/500, minibatch 0017, Loss (MSE) 0.228196
// Epoch 500/500, minibatch 0018, Loss (MSE) 0.222008
// Epoch 500/500, minibatch 0019, Loss (MSE) 0.230757
// Epoch 500/500, minibatch 0020, Loss (MSE) 0.203405
// Epoch 500/500, minibatch 0021, Loss (MSE) 0.221081
// Epoch 500/500, minibatch 0022, Loss (MSE) 0.21573
// Epoch 500/500, minibatch 0023, Loss (MSE) 0.215744
// Epoch 500/500, minibatch 0024, Loss (MSE) 0.221523
// Epoch 500/500, minibatch 0025, Loss (MSE) 0.218495
// Epoch 500/500, minibatch 0026, Loss (MSE) 0.215803
// Epoch 500/500, minibatch 0027, Loss (MSE) 0.218166
// Epoch 500/500, minibatch 0028, Loss (MSE) 0.232809
// Epoch 500/500, minibatch 0029, Loss (MSE) 0.21593
// Epoch 500/500, minibatch 0030, Loss (MSE) 0.226292
// Training accuracy (MSE): 0.221198
// Test accuracy: (MSE): 0.231876
